# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/NetOptik/blob/Shironin-Igor-branch/Shironin%20Igor/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22_%D1%84%D0%B8%D0%BD%D0%B0%D0%BB_%D0%B7%D0%B0%D0%B4%D0%B0%D1%87%D0%B8%222%22_%22%D1%81%D1%82%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0_%22_%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BA%D0%BB%D0%B0%D1%81%D1%81%D0%B8%D1%84%D0%B8%D0%BA%D0%B0%D1%86%D0%B8%D0%B8_%D0%BE%D1%87%D0%BA%D0%BE%D0%B2_%D0%BF%D0%BE_%D0%BC%D0%B0%D1%82%D0%B5%D1%80%D0%B8%D0%B0%D0%BB%D0%B0%D0%BC_%D0%B8%D0%B7%D0%B3%D0%BE%D1%82%D0%BE%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D1%8F%22%22%22%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Создание модели нейросети для распознавания очков по материалу.**
#
#    Задача стажера: разработка модели нейросети, которая сможет классифицировать очки по материалам - комбинированные, металл, пластик. Получение необходимых данных с сайта и их размещение в соответствующих директориях для последующего обучения модели. (По заданным категориям качаем с сайта изображения и размещаем п
# о 3 папкам, потом запускаем модель.)

# %% [markdown]
# Были получены необходимые файлы с изображениями и размещены в папках ['Металл 418', 'Пластик 500', 'Комбинированный 250'] на гугл диске.
#  Для удобства последующей загрузки в Сolab папки были заархивированны в архив img.zip. Далее было принято решение использовать модель нейронной сети из курса УИИ : Базовый блок | Сверточные нейронные сети
#
# Загружены стандартные библиотеки , необходимые для подготовки выборок и построения модели.

# %% [markdown]
# # Библиотеки

# %%
# Работа с массивами
import numpy as np
# Генерация случайных чисел
import random
# Модель
from tensorflow.keras.models import Sequential
# Основные слои
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
# Оптимизатор
from tensorflow.keras.optimizers import Adam
# Матрица ошибок классификатора
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# Подключение модуля для загрузки данных из облака
import gdown
# Инструменты для работы с файлами
import  requests, zipfile
import os
# Отрисовка графиков
import matplotlib.pyplot as plt
# Инструменты для работы с изображениями
from PIL import Image, ImageEnhance
# Математические функции
import math
# Метод разделения выборок
from sklearn.model_selection import train_test_split
# Рисование графиков в ячейках Colab
# %matplotlib inline

# %% [markdown]
# Загружаем img.zip, разархивируем и смотрим на то что там находится

# %% [markdown]
# # Загрузка изображений

# %% [markdown]
# ## Подключение гугл диска

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Открываем доступ к файлу, получаем ссылку на архив с изображениями, загружаем и разархивируем

# %%
# https://drive.google.com/file/d/1Ku1Dw9CTQOSvhd5nmkRDb1x70-F4Ttug/view?usp=sharing
f_1 = '1Ku1Dw9CTQOSvhd5nmkRDb1x70-F4Ttug'# нужна только эта часть ссылки
gdown.download(f'https://drive.google.com/uc?id={f_1}', None, quiet=True)
# Out:
# 'img.zip'

# %%
# Разархивация датасета в директорию 'content/img'
# !unzip -qo "img.zip" -d /content/img
# !unzip -qo -x "img.zip" -d /content/img # Код, без информационных файлов
# Out:
# Комбинированный 250/:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/),
#          continuing with "central" filename version
# Комбинированный 250/aigner-ea317-423-s2-1 (3).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/aigner-ea317-423-s2-1 (3).jpg),
#          continuing with "central" filename version
# Комбинированный 250/aigner-ea317-423-s2-2 (2).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/aigner-ea317-423-s2-2 (2).jpg),
#          continuing with "central" filename version
# Комбинированный 250/alexander-mcqueen-amq4257-8sm-s2-1 (3).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/alexander-mcqueen-amq4257-8sm-s2-1 (3).jpg),
#          continuing with "central" filename version
# Комбинированный 250/alexander-mcqueen-amq4257-8sm-s2-2 (2).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/alexander-mcqueen-amq4257-8sm-s2-2 (2).jpg),
#          continuing with "central" filename version
# Комбинированный 250/ana-hickmann-ah1237-04b-s2-1 (2).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/ana-hickmann-ah1237-04b-s2-1 (2).jpg),
#          continuing with "central" filename version
# Комбинированный 250/ana-hickmann-ah1237-04b-s2-2 (1).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/ana-hickmann-ah1237-04b-s2-2 (1).jpg),
#          continuing with "central" filename version
# Комбинированный 250/ana-hickmann-ah1246-03a-s2-1 (2).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/ana-hickmann-ah1246-03a-s2-1 (2).jpg),
#          continuing with "central" filename version
# Комбинированный 250/ana-hickmann-ah1246-03a-s2-2 (1).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/ana-hickmann-ah1246-03a-s2-2 (1).jpg),
#          continuing with "central" filename version
# Комбинированный 250/ana-hickmann-ah1249n-01a-s2-1 (2).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/ana-hickmann-ah1249n-01a-s2-1 (2).jpg),
#          continuing with "central" filename version
# Комбинированный 250/ana-hickmann-ah1249n-01a-s2-2 (1).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/ana-hickmann-ah1249n-01a-s2-2 (1).jpg),
#          continuing with "central" filename version
# Комбинированный 250/ana-hickmann-ah1277-02a-s2-1 (2).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/ana-hickmann-ah1277-02a-s2-1 (2).jpg),
#          continuing with "central" filename version
# Комбинированный 250/ana-hickmann-ah1277-02a-s2-2 (1).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/ana-hickmann-ah1277-02a-s2-2 (1).jpg),
#          continuing with "central" filename version
# Комбинированный 250/ana-hickmann-ah1289-06a-s2-1 (2).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/ana-hickmann-ah1289-06a-s2-1 (2).jpg),
#          continuing with "central" filename version
# Комбинированный 250/ana-hickmann-ah1289-06a-s2-2 (1).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/ana-hickmann-ah1289-06a-s2-2 (1).jpg),
#          continuing with "central" filename version
# Комбинированный 250/ana-hickmann-ah1436-g21-s2-1 (2).jpg:  mismatching "local" filename (╨Ъ╨╛╨╝╨▒╨╕╨╜╨╕╤А╨╛╨▓╨░╨╜╨╜╤Л╨╣ 250/ana-hickmann-ah
s2-1 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-124-c33-s2-1 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-124-c33-s2-2 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-124-c33-s2-2 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-124-c35-s2-1 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-124-c35-s2-1 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-124-c35-s2-2 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-124-c35-s2-2 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-135-c31-s2-1 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-135-c31-s2-1 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-135-c31-s2-2 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-135-c31-s2-2 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-149-c33-s2-1 (15).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-149-c33-s2-1 (15).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-149-c33-s2-2 (14).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-149-c33-s2-2 (14).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-158-c31-s2-1 (21).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-158-c31-s2-1 (21).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-158-c31-s2-2 (20).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-158-c31-s2-2 (20).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-158-c33-s2-1 (30).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-158-c33-s2-1 (30).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-158-c33-s2-2 (29).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-158-c33-s2-2 (29).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-159-c31-s2-1 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-159-c31-s2-1 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-159-c31-s2-2 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-159-c31-s2-2 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-160-c01-s2-1 (39).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-160-c01-s2-1 (39).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-160-c01-s2-2 (38).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-160-c01-s2-2 (38).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-381-с2-s2-1 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-381-╤Б2-s2-1 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-381-с2-s2-2 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-381-╤Б2-s2-2 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-kids-lso1093-c4-s2-1 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-kids-lso1093-c4-s2-1 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-kids-lso1093-c4-s2-2 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-kids-lso1093-c4-s2-2 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-kids-lso1094-c4-s2-1 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-kids-lso1094-c4-s2-1 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-kids-lso1094-c4-s2-2 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-kids-lso1094-c4-s2-2 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-kids-lso1097-c2-s2-1 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-kids-lso1097-c2-s2-1 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-kids-lso1097-c2-s2-2 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-kids-lso1097-c2-s2-2 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-kids-lso1097-c4-s2-1 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-kids-lso1097-c4-s2-1 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-kids-lso1097-c4-s2-2 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-kids-lso1097-c4-s2-2 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-kids-mс01-10-c04-s2-1 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-kids-m╤Б01-10-c04-s2-1 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-kids-mс01-10-c04-s2-2 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-kids-m╤Б01-10-c04-s2-2 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-kids-mс01-810-c11-s2-1 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-kids-m╤Б01-810-c11-s2-1 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/la-stella-kids-mс01-810-c11-s2-2 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/la-stella-kids-m╤Б01-810-c11-s2-2 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3040148-s2-1 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3040148-s2-1 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3040148-s2-2 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3040148-s2-2 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3041746-s2-1 (1).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3041746-s2-1 (1).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3041746-s2-2 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3041746-s2-2 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3050549-s2-1 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3050549-s2-1 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3050549-s2-2 (3).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3050549-s2-2 (3).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3170854-s2-1 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3170854-s2-1 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3170854-s2-2 (3).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3170854-s2-2 (3).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3180448-s2-1 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3180448-s2-1 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3180448-s2-2 (3).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3180448-s2-2 (3).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3180748-s2-1 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3180748-s2-1 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3180748-s2-2 (3).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3180748-s2-2 (3).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3180848-s2-1 (2).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3180848-s2-1 (2).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3180848-s2-2 (3).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3180848-s2-2 (3).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3180948-s2-1 (6).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3180948-s2-1 (6).jpg),
#          continuing with "central" filename version
# Пластик 500/nanovista-nao3180948-s2-2 (7).jpg:  mismatching "local" filename (╨Я╨╗╨░╤Б╤В╨╕╨║ 500/nanovista-nao3180948-s2-2 (7).jpg),
#          continuing with "central" filename version

# %% [markdown]
# ## Удаляем информационные файлы

# %%
# !rm /content/img/Комбинированный\ 250/desktop.ini
# !rm /content/img/Металл\ 418/desktop.ini
# !rm /content/img/Пластик\ 500/desktop.ini

# %% [markdown]
# ## Смотрим какие папки находятся в архиве

# %%
# Папка с папками картинок, рассортированных по категориям
IMAGE_PATH = '/content/img/'
os.listdir(IMAGE_PATH)
# Out:
# ['Металл 418', 'Пластик 500', 'Комбинированный 250']

# %% [markdown]
# # Cоздание списков путей к файлам и меток к ним

# %%
# Определение списка имен классов
CLASS_LIST = sorted(os.listdir(IMAGE_PATH)) # можно не сортировать CLASS_LIST = os.listdir(IMAGE_PATH)
# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)
# Проверка результата
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}')
# Out:
# Количество классов: 3, метки классов: ['Комбинированный 250', 'Металл 418', 'Пластик 500']

# %%
# Создание заготовки для изображений всех классов
fig, axs = plt.subplots(1, CLASS_COUNT, figsize=(25, 5))

# Для всех номеров классов:
for i in range(CLASS_COUNT):
    # Формирование пути к папке содержимого класса
    path = f'{IMAGE_PATH}{CLASS_LIST[i]}/'
    # Выбор случайного фото из i-го класса
    img_path = path + random.choice(os.listdir(path))
    # Отображение фотографий
    axs[i].set_title(CLASS_LIST[i])
    axs[i].imshow(Image.open(img_path))
    axs[i].axis('off')

# Отрисовка всего полотна
plt.show()

# %%
data_files = []                           # Cписок путей к файлам картинок
data_labels = []                          # Список меток классов, соответствующих файлам


for class_label in range(CLASS_COUNT):    # Для всех классов по порядку номеров (их меток)
    class_name = CLASS_LIST[class_label]  # Выборка имени класса из списка имен
    class_path = IMAGE_PATH + class_name  # Формирование полного пути к папке с изображениями класса
    class_files = os.listdir(class_path)  # Получение списка имен файлов с изображениями текущего класса
    print(f'Размер класса {class_name} составляет {len(class_files)} фото')

    # Добавление к общему списку всех файлов класса с добавлением родительского пути
    data_files += [f'{class_path}/{file_name}' for file_name in class_files]

    # Добавление к общему списку меток текущего класса - их ровно столько, сколько файлов в классе
    data_labels += [class_label] * len(class_files)
    print('Общий размер базы для обучения:', len(data_labels))
# Out:
# Размер класса Комбинированный 250 составляет 514 фото
# Общий размер базы для обучения: 514
# Размер класса Металл 418 составляет 418 фото
# Общий размер базы для обучения: 932
# Размер класса Пластик 500 составляет 499 фото
# Общий размер базы для обучения: 1431

# %% [markdown]
# Видим что общая база фотографий мала для качественного обучения. Поэтому необходимо ее увеличить за счет аугментации. Для начала посмотрим на какое-нибудь изображение из базы.

# %% [markdown]
# # Просмотр 1300-ого фото, размера фото и метки из общей базы размера 1431

# %%
img  = Image.open(data_files[1300])
print(img.size)
print(data_labels[1300])
img
# Out:
# (900, 600)
# 2
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600>

# %% [markdown]
# Понятно что памяти для работы с изображениями такого размера не хватит. Было проведено несколько экпериментов по подбору размера изображения.
# Размерность 128х64 подошла.

# %% [markdown]
# # Получение списка файлов data_img c размерностью 128х64

# %%
IMG_WIDTH           = 128       # Ширина изображения для нейросети
IMG_HEIGHT          = 64      # Высота изображения для нейросети

# %%
data_img = []
for i in range(len(data_files)):
  img_old  = Image.open( data_files[i])
  img = img_old.resize((IMG_WIDTH ,IMG_HEIGHT ))
  data_img.append(img)

# %%
img1 = data_img[5]

# %%
img1
# Out:
# <PIL.Image.Image image mode=RGB size=128x64>

# %% [markdown]
# Для аугментации бало выбрано несколько методов, которые по моему мнению не должно было повлиять на качество обучения.
#
# 1.   Угол поворота
# не более 10 градусов  иначе при обрезке черных углов и восстановления размера изображения часть фото и информации будет потеряна
# 2.  Яркость и Контрастность с коэфициентом изменения не более 40 %
# 3.  Отражение
#
#
# Для получения аугментированного изображения была написана функция рандомного применения изменений

# %% [markdown]
# # Создание аугментированного списка изображений

# %% [markdown]
# ## Объявление вспомогательных функций

# %%
# Сравнение двух изображений
def show_image_pair(img1, img2): #
    # Cоздание полотна для рисования двух изображений
    fig, axs = plt.subplots(1, 2, figsize=(4, 2))
    # Исходное изображение
    axs[0].imshow(img1)
    axs[0].axis('off')
    # Модифицированное изображение
    axs[1].imshow(img2)
    axs[1].axis('off')
    # Вывод изображений
    plt.show()

# %%
# подрезка изображения чтобы не было черных углов
def rotated_rect(w,                       # Ширина изображения
                 h,                       # Высота изображения
                 angle                    # Угол поворота в градусах
                 ):
    angle = math.radians(angle)
    width_is_longer = w >= h
    side_long, side_short = (w,h) if width_is_longer else (h,w)

    sin_a, cos_a = abs(math.sin(angle)), abs(math.cos(angle))

    if side_short <= 2.*sin_a*cos_a*side_long or abs(sin_a-cos_a) < 1e-10:
        x = 0.5 * side_short
        wr, hr = (x/sin_a, x/cos_a) if width_is_longer else (x/cos_a, x/sin_a)
    else:
        cos_2a = cos_a*cos_a - sin_a*sin_a
        wr, hr = (w*cos_a - h*sin_a)/cos_2a, (h*cos_a - w*sin_a)/cos_2a

    return wr, hr # Ширина и Высота прямоугольника обрезки

# %%
 # функция поворота на случайный угол (в градусах) с учетом необходимой обрезки
 # + востановление размеров
def random_rot(x,      # Подаваемое изображение
               ang                        # Максимальный угол поворота
               ):
    # Случайное значение угла в диапазоне [-ang, ang]
  a = random.uniform(-1., 1.) * ang
    # Вращение картинки с расширением рамки
  r = x.rotate(a, expand=True)
    # Вычисление размеров прямоугольника обрезки максимальной площади
    # для размеров исходной картинки и угла поворота в градусах
  crop_w, crop_h = rotated_rect(x.width, x.height, a)
    # Обрезка повернутого изображения и возврат результата
  w, h = r.size
  y = r.crop(((w - crop_w)*0.5, (h - crop_h)*0.5,
                   (w + crop_w)*0.5, (h + crop_h)*0.5))
  y = y.resize((x.width,x.height))
  return y              # Полученное изображение

# %%
## Функция изменения контрасности
def random_contrast(x,                    # Подаваемое изображение
                    level                 # Максимальное отклонение коэффициента контраста от нормы - число от 0. до 1.
                    ):
    enh = ImageEnhance.Contrast(x)        # Создание экземпляра класса Contrast
    factor = random.uniform(1. - level,
                            1. + level)   # Cлучайный коэффициент контраста из указанного интервала
    return enh.enhance(factor)            # Получаемое изображение с изменением коэффициента контраста

# %%
 ## Функция изменения яркости
 def random_brightness(x,                  # Подаваемое изображение
                      level               # Максимальное отклонение коэффициента яркости от нормы - число от 0. до 1.
                      ):
    enh = ImageEnhance.Brightness(x)      # Создание экземпляра класса Brightness
    factor = random.uniform(1. - level,
                            1. + level)   # Cлучайный коэффициент яркости из указанного интервала
    return enh.enhance(factor)             # Получаемое изображение с изменением коэффициента яркости

# %%
## Функция отражения
def  trans_img(img1) :
  img2 = img1.transpose(Image.FLIP_LEFT_RIGHT) # отражение
  return img2

# %%
# Задание максимального угла поворота и
# максимального модуля изменения яркости и контрастности
ang = 10
level = 0.4

# %%
# Функция Аугментации
def aug (img, ang, level):
    # Cоздание списка модификаций
  mod_oper = [random_rot(img,ang),
                trans_img(img),
                random_contrast(img,level),
                random_brightness(img,level)]

    # Cлучайное количество изменений из списка; минимум одно изменение
  mod_count = random.randrange(len(mod_oper) + 1)

    # Случайный отбор индексов изменений в количестве mod_count без повторений
  mod_list = random.sample(range(len(mod_oper)), mod_count)

    # Применение модификаций по индексам из mod_list
  for mod_index in mod_list:
        img = mod_oper[mod_index]

    # Возврат результата
  return img

# %% [markdown]
# ## Отображение 100-ого изображения и аугментированного

# %%
img1 = data_img[100]
img2 = aug(img1,ang, level)
show_image_pair(img1, img2)

# %% [markdown]
# Теперь аугментируем весь список изображений с сохранением меток

# %% [markdown]
# ## Функция аугментации одного изображения n раз

# %%
# функция для получения списка из n аугментированых изображений + родное
# со списком одинаковых меток(mark)

def aug_list(img, n, mark):
  img_list = [img]
  a_list = [mark]
  for i in range(n):
    img_list += [aug(img,ang,level)]
    a_list.append(mark)
  return img_list , a_list

# %%
fig, axs = plt.subplots(1, 6, figsize=(4, 2))

a,b  = aug_list(data_img[1000],5,data_labels[1000])
for i in range(6):
    # Исходное изображение
  axs[i].imshow(a[i])
  axs[i].axis('off')

#     # Вывод изображений
plt.show()
b
# Out:
# [2, 2, 2, 2, 2, 2]

# %% [markdown]
# ## Функция аугментации списка изображений в n раз с сохранением меток

# %%
def aug_list_n (img_list,mark_list, n) :
  data_x = []
  data_y = []
  for i in range(len(img_list )):
    list_img ,list_a = aug_list(img_list[i],n-1,mark_list[i])
    for j in range(len(list_img )):
       data_x.append(list_img[j])
       data_y.append(list_a[j])
  return data_x, data_y

# %% [markdown]
# ## Получение аугментированного списка изображений

# %%
n = 5

# %%
data_x, data_y = aug_list_n (data_img,data_labels, n)

# %%
print(data_x[1000].size)
print(len(data_x))
data_x[1000:1005]
# Out:
# (128, 64)
# 7155
# [<PIL.Image.Image image mode=RGB size=128x64>,
#  <PIL.Image.Image image mode=RGB size=128x64>,
#  <PIL.Image.Image image mode=RGB size=128x64>,
#  <PIL.Image.Image image mode=RGB size=128x64>,
#  <PIL.Image.Image image mode=RGB size=128x64>]

# %%
print(len(data_y))
data_y[1000]
# Out:
# 7155
# 0

# %% [markdown]
# Для подготовки выборок был использован метод train_test_split.
#
# Этот метод позволяет получить пропорциональные выборки в соответствии с классами изображений. И подаваемые в обучение модели данные будут содержать все классы.

# %% [markdown]
# # Подготовка выборок

# %%
print(data_x[1000].size)

# Преобразование списка в массив и нормализовка изображений
data_images = np.array([np.array(img) for img in data_x])/255

# Проверка размерности
print(data_images.shape)
# Out:
# (128, 64)
# (7155, 64, 128, 3)

# %%
print(data_images[600].shape)
print(data_y[600])
data_images[600]
# Out:
# (64, 128, 3)
# 0
# array([[[0.97254902, 0.96862745, 0.96078431],
#         [0.97647059, 0.97254902, 0.96470588],
#         [0.98039216, 0.97647059, 0.96862745],
#         ...,
#         [0.9254902 , 0.9254902 , 0.9254902 ],
#         [0.92156863, 0.92156863, 0.92156863],
#         [0.91372549, 0.91372549, 0.91372549]],
#
#        [[0.97647059, 0.97254902, 0.96470588],
#         [0.97647059, 0.97254902, 0.96470588],
#         [0.98039216, 0.97647059, 0.96862745],
#         ...,
#         [0.92941176, 0.92941176, 0.92941176],
#         [0.9254902 , 0.9254902 , 0.9254902 ],
#         [0.91764706, 0.91764706, 0.91764706]],
#
#        [[0.97647059, 0.97254902, 0.96470588],
#         [0.97647059, 0.97254902, 0.96470588],
#         [0.98039216, 0.97647059, 0.96862745],
#         ...,
#         [0.92941176, 0.92941176, 0.92941176],
#         [0.9254902 , 0.9254902 , 0.9254902 ],
#         [0.92156863, 0.92156863, 0.92156863]],
#
#        ...,
#
#        [[0.98431373, 0.98431373, 0.98431373],
#         [0.98431373, 0.98431373, 0.98431373],
#         [0.98823529, 0.98823529, 0.98823529],
#         ...,
#         [0.99607843, 0.99607843, 0.99607843],
#         [0.99607843, 0.99607843, 0.99607843],
#         [0.99607843, 0.99607843, 0.99607843]],
#
#        [[0.98431373, 0.98431373, 0.98431373],
#         [0.98431373, 0.98431373, 0.98431373],
#         [0.98823529, 0.98823529, 0.98823529],
#         ...,
#         [0.99607843, 0.99607843, 0.99607843],
#         [0.99607843, 0.99607843, 0.99607843],
#         [0.99607843, 0.99607843, 0.99607843]],
#
#        [[0.98823529, 0.98823529, 0.98823529],
#         [0.98823529, 0.98823529, 0.98823529],
#         [0.98823529, 0.98823529, 0.98823529],
#         ...,
#         [0.99607843, 0.99607843, 0.99607843],
#         [0.99607843, 0.99607843, 0.99607843],
#         [0.99607843, 0.99607843, 0.99607843]]])

# %%
data_images[1].shape
# Out:
# (64, 128, 3)

# %%
x_data = np.array(data_images)          # Перевод общего списка изображений в numpy-массив
y_data = np.array(data_y)            # Перевод общего списка меток класса в numpy-массив
print(f'Общий массив данных изображений следующей формы: {x_data.shape}')
print(f'Общий массив меток классов следующей формы: {y_data.shape}')
# Out:
# Общий массив данных изображений следующей формы: (7155, 64, 128, 3)
# Общий массив меток классов следующей формы: (7155,)

# %%
# Преобразование данных в формат one_hot_encoding
from tensorflow.keras.utils import to_categorical
y_data = to_categorical(y_data, 3)
y_data[5]
# Out:
# array([1., 0., 0.], dtype=float32)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, # ----------------- датасет с изображениям
                                                    y_data, # ----------------- датасет с метками
                                                    test_size = 0.1, # --- процент тестовых значений
                                                    shuffle=True, # ------ перемешивание
                                                    random_state=42) # ---

# %%
x_train, x_val, y_train, y_val = train_test_split(x_data, # ----------------- датасет с изображениям
                                                    y_data, # ----------------- датасет с метками
                                                    test_size = 0.2, # --- процент тестовых значений
                                                    shuffle=True, # ------ перемешивание
                                                    random_state=42) # ---
print(f'Общий массив данных изображений следующей формы: {x_train.shape}')
print(f'Общий массив меток классов следующей формы: {y_train.shape}')
print(f'Общий массив данных проверочных изображений следующей формы: {x_val.shape}')
print(f'Общий массив проверочных меток классов следующей формы: {y_val.shape}')
print(f'Общий массив тестовых данных  изображений следующей формы: {x_test.shape}')
print(f'Общий массив тестовых меток классов следующей формы: {y_test.shape}')
# Out:
# Общий массив данных изображений следующей формы: (5724, 64, 128, 3)
# Общий массив меток классов следующей формы: (5724, 3)
# Общий массив данных проверочных изображений следующей формы: (1431, 64, 128, 3)
# Общий массив проверочных меток классов следующей формы: (1431, 3)
# Общий массив тестовых данных  изображений следующей формы: (716, 64, 128, 3)
# Общий массив тестовых меток классов следующей формы: (716, 3)

# %% [markdown]
# # Cоздание модели

# %%
EPOCHS              = 150         # Число эпох обучения
BATCH_SIZE          = 24                    # Размер батча для обучения модели
OPTIMIZER           = Adam(0.0001)
CLASS_COUNT         = 3

IMG_CHANNELS        = 3

# %%
# Создание последовательной модели
model_conv = Sequential()

# Первый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH  , IMG_CHANNELS)))
model_conv.add(BatchNormalization())

# Второй сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))

# Третий сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())
model_conv.add(Dropout(0.2))

# Четвертый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Пятый сверточный слой
model_conv.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())

# Шестой сверточный слой
model_conv.add(Conv2D(1024, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Слой преобразования многомерных данных в одномерные
model_conv.add(Flatten())

# Промежуточный полносвязный слой
model_conv.add(Dense(2048, activation='relu'))

# Промежуточный полносвязный слой
model_conv.add(Dense(4096, activation='relu'))
# Выходной полносвязный слой с количеством нейронов по количесту классов
model_conv.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
    # Вывод сводки
model_conv.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 128, 256)      7168
#
#  batch_normalization (Batch  (None, 64, 128, 256)      1024
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 64, 128, 256)      590080
#
#  max_pooling2d (MaxPooling2  (None, 21, 42, 256)       0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 21, 42, 256)       590080
#
#  batch_normalization_1 (Bat  (None, 21, 42, 256)       1024
#  chNormalization)
#
#  dropout (Dropout)           (None, 21, 42, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 21, 42, 256)       590080
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 14, 256)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 7, 14, 256)        0
#
#  conv2d_4 (Conv2D)           (None, 7, 14, 512)        1180160
#
#  batch_normalization_2 (Bat  (None, 7, 14, 512)        2048
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 7, 14, 1024)       4719616
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 4, 1024)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 4, 1024)        0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 2048)              16779264
#
#  dense_1 (Dense)             (None, 4096)              8392704
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 32865539 (125.37 MB)
# Trainable params: 32863491 (125.36 MB)
# Non-trainable params: 2048 (8.00 KB)
# _________________________________________________________________

# %% [markdown]
# Т.к. база для обучения не большая, то чтобы зафиксировать лучшие веса модели необходимо было использовать метод callback. Этод метод был использован для фиксации лучшей модели - ModelCheckpoint и остановки обучения в случии не наступления улучшения модели - EarlyStopping.
#
# Для этого была использованна библиотека keras.callbacks

# %% [markdown]
# # Настройка callback с сохранением лучшей модели и остановкой обучения

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
# Создание обратного вызова EarlyStopping
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1)
checkpoint = ModelCheckpoint('/content/drive/MyDrive/model/' + 'best_model2.h5', monitor='val_accuracy',
                             save_best_only=True, mode='max', verbose=1)

# %%
model_conv.compile(optimizer=OPTIMIZER,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %% [markdown]
# Чтобы пользоваться обученной моделью и не запускать обучение модели каждый раз настраиваем в callback сохранение лучшей модели best_model2.h5 на гугл диск.
#
# для загрузки модели импортируем модуль load_model из библиотеки tensorflow.keras.models

# %% [markdown]
# # Загрузка обученной модели и дообучение

# %%
from tensorflow.keras.models import load_model

model_conv = load_model("/content/drive/MyDrive/model/best_model2.h5")

# %% [markdown]
# Если хотим обучить модель с нуля , предыдущий код запускать не надо

# %%
 # Обучение модели с заданными параметрами
history = model_conv.fit( x_train,y_train,
                        epochs=EPOCHS  ,
                      batch_size=BATCH_SIZE,
                        validation_data=(x_val, y_val),callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/150
# 239/239 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9497
# Epoch 1: val_accuracy improved from -inf to 0.84556, saving model to /content/drive/MyDrive/model/best_model2.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 239/239 [==============================] - 69s 208ms/step - loss: 0.1305 - accuracy: 0.9497 - val_loss: 0.4779 - val_accuracy: 0.8456
# Epoch 2/150
# 239/239 [==============================] - ETA: 0s - loss: 0.0835 - accuracy: 0.9668
# Epoch 2: val_accuracy improved from 0.84556 to 0.95667, saving model to /content/drive/MyDrive/model/best_model2.h5
# 239/239 [==============================] - 56s 234ms/step - loss: 0.0835 - accuracy: 0.9668 - val_loss: 0.1212 - val_accuracy: 0.9567
# Epoch 3/150
# 239/239 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9764
# Epoch 3: val_accuracy did not improve from 0.95667
# 239/239 [==============================] - 46s 190ms/step - loss: 0.0532 - accuracy: 0.9764 - val_loss: 0.2622 - val_accuracy: 0.9182
# Epoch 4/150
# 239/239 [==============================] - ETA: 0s - loss: 0.0632 - accuracy: 0.9738
# Epoch 4: val_accuracy did not improve from 0.95667
# 239/239 [==============================] - 45s 190ms/step - loss: 0.0632 - accuracy: 0.9738 - val_loss: 0.9824 - val_accuracy: 0.8763
# Epoch 5/150
# 239/239 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9726
# Epoch 5: val_accuracy did not improve from 0.95667
# 239/239 [==============================] - 43s 180ms/step - loss: 0.0580 - accuracy: 0.9726 - val_loss: 0.1671 - val_accuracy: 0.9462
# Epoch 6/150
# 239/239 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9755
# Epoch 6: val_accuracy did not improve from 0.95667
# 239/239 [==============================] - 43s 179ms/step - loss: 0.0541 - accuracy: 0.9755 - val_loss: 0.4951 - val_accuracy: 0.8679
# Epoch 7/150
# 239/239 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9825
# Epoch 7: val_accuracy did not improve from 0.95667
# 239/239 [==============================] - 43s 179ms/step - loss: 0.0368 - accuracy: 0.9825 - val_loss: 0.1665 - val_accuracy: 0.9490
# Epoch 8/150
# 239/239 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9810
# Epoch 8: val_accuracy did not improve from 0.95667
# 239/239 [==============================] - 45s 190ms/step - loss: 0.0382 - accuracy: 0.9810 - val_loss: 0.2686 - val_accuracy: 0.9287
# Epoch 9/150
# 239/239 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9776
# Epoch 9: val_accuracy did not improve from 0.95667
# 239/239 [==============================] - 43s 179ms/step - loss: 0.0513 - accuracy: 0.9776 - val_loss: 0.4048 - val_accuracy: 0.8924
# Epoch 10/150
# 239/239 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9818
# Epoch 10: val_accuracy did not improve from 0.95667
# 239/239 [==============================] - 45s 190ms/step - loss: 0.0373 - accuracy: 0.9818 - val_loss: 0.4509 - val_accuracy: 0.8735
# Epoch 11/150
# 239/239 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9834
# Epoch 11: val_accuracy did not improve from 0.95667
# 239/239 [==============================] - 43s 179ms/step - loss: 0.0361 - accuracy: 0.9834 - val_loss: 0.1984 - val_accuracy: 0.9231
# Epoch 12/150
# 239/239 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9801
# Epoch 12: val_accuracy did not improve from 0.95667
# 239/239 [==============================] - 45s 190ms/step - loss: 0.0489 - accuracy: 0.9801 - val_loss: 0.2434 - val_accuracy: 0.9189
# Epoch 12: early stopping

# %% [markdown]
# Используем модуль pickle  для сохранения и последующего использования истории обнучения

# %% [markdown]
# # Сохранение и загрузка истории обучения для последующего использования

# %%
import pickle

# Сохранение переменной history
with open('/content/drive/My Drive/model/history2.pkl', 'wb') as f:
    pickle.dump(history, f)

# %%
# Загрузка переменной history с Google Диска
with open('/content/drive/My Drive/model/history2.pkl', 'rb') as f:
    history = pickle.load(f)

# %% [markdown]
# # Отображение графиков обучения

# %%
# Создание полотна для рисунка
plt.figure(1, figsize=(18, 5))

# Задание первой (левой) области для построения графиков
plt.subplot(1, 2, 1)
# Отрисовка графиков 'loss' и 'val_loss' из значений словаря store_learning.history
plt.plot(history.history['loss'],
         label='Значение ошибки на обучающем наборе')
plt.plot(history.history['val_loss'],
         label='Значение ошибки на проверочном наборе')
# Задание подписей осей
plt.xlabel('Эпоха обучения')
plt.ylabel('Значение ошибки')
plt.legend()

# Задание второй (правой) области для построения графиков
plt.subplot(1, 2, 2)
# Отрисовка графиков 'accuracy' и 'val_accuracy' из значений словаря store_learning.history
plt.plot(history.history['accuracy'],
         label='Доля верных ответов на обучающем наборе')
plt.plot(history.history['val_accuracy'],
         label='Доля верных ответов на проверочном наборе')
# Задание подписей осей
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()

# Фиксация графиков и рисование всей картинки
plt.show()

# %% [markdown]
# # Загрузка лучшей модели и проверка ее работы на тестовых данных

# %%
from tensorflow.keras.models import load_model

model_conv = load_model("/content/drive/MyDrive/model/best_model2.h5")

# %% [markdown]
# ## Доля верных ответов на тестовых данных, в процентах: evaluate

# %%
scores = model_conv.evaluate(x_test, y_test, verbose=1)
print(scores)
print('Доля верных ответов на тестовых данных, в процентах: {:7.4%}'.format(scores[1]))
# Out:
# 23/23 [==============================] - 3s 47ms/step - loss: 0.1157 - accuracy: 0.9567
# [0.11565909534692764, 0.9567039012908936]
# Доля верных ответов на тестовых данных, в процентах: 95.6704%

# %% [markdown]
# # Построение "Матрици  ошибок"

# %%
# Импорт метода построения confusion_matrix
from sklearn.metrics import confusion_matrix
# Импорт метода визуализации confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# Получение предсказанных значений модели для тестового набора данных

y_pred = model_conv.predict(x_test)
 # округление до целых чисел и преобразование в одномерный массив
#y_pred = np.round(y_pred).flatten()  Мы пойдем другим путем более наглядным

# Получение истинных значений тестового набора данных
# y_test = test_a_generator.classes
y_true = y_test
# Out:
# 23/23 [==============================] - 1s 48ms/step

# %%
# x = np.expand_dims(x, axis=0)
x1 =  np.expand_dims(x_test[20], axis=0)
# Проверка формы данных
print(x1.shape)
# Out:
# (1, 64, 128, 3)

# %%
# Распознавание примера
prediction = model_conv.predict(x1)
print(prediction)
# Out:
# 1/1 [==============================] - 0s 311ms/step
# [[3.9279188e-05 4.8313231e-10 9.9996066e-01]]

# %%
pred = np.argmax(y_true[20])
print(f'Распознанный класс: {pred}')
pred
# Out:
# Распознанный класс: 2
# 2

# %%
y_pred[1]
# Out:
# array([1.2385353e-05, 9.9998760e-01, 4.1125277e-09], dtype=float32)

# %%
y_true[1]
# Out:
# array([0., 1., 0.], dtype=float32)

# %%
len(y_true)
# Out:
# 716

# %%
y_true[1:5]
# Out:
# array([[0., 1., 0.],
#        [0., 1., 0.],
#        [1., 0., 0.],
#        [0., 0., 1.]], dtype=float32)

# %%
from pandas.core.arrays.arrow import array
true_y= []
pred_y =[]
for i in range(len(y_true)):
  true_y.append(np.argmax(y_true[i]))
  pred_y.append(np.argmax(y_pred[i]))
true = np.array(true_y)
pred = np.array(pred_y)

print(true[1:5])
print(pred[1:5])
# Out:
# [1 1 0 2]
# [1 1 0 2]

# %%
# Построение матрицы ошибок
cm = confusion_matrix(true, pred)

print(cm)
# Out:
# [[231  13  11]
#  [  5 204   0]
#  [  2   0 250]]

# %%
# Построение confusion matrix
#cm = confusion_matrix(y_true, y_pred)
cm = confusion_matrix(true, pred)
TEST_CLASS_LIST = sorted(os.listdir(IMAGE_PATH))

# # Визуализация матрицы ошибок
# disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels = ['Пластик', 'Метал'])
display_label = np.arange(len(TEST_CLASS_LIST))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels = display_label)
disp.plot()

plt.title('Матрица ошибок')
plt.xticks(display_label, TEST_CLASS_LIST, rotation=45)
plt.yticks(display_label, TEST_CLASS_LIST, rotation=45)
plt.xlabel('Предсказания модели')
plt.ylabel('Правильные ответы')
plt.show()

# %% [markdown]
# # Выводы

# %% [markdown]
#   Использовалась модель представленная в матариалах УИИ:
#
#     Базовый блок | Сверточные нейронные сети
#
#   Размер изображений использовался:
#
# IMG_WIDTH = 128   # Ширина изображения для нейросети
#
# IMG_HEIGHT  = 64  # Высота изображения для нейросети

# %% [markdown]
# Точность распознавания на тестовой выборке была достигнута 95,67 %. Скорее всего можно будет достигнуть лучшей точности если увеличить объем реальных а не аугментированных данных или если увеличить размер изображения подаваемого в нейросеть, что не было сделанноо только из за ограниченного объема бесплатной памяти в Colab/
