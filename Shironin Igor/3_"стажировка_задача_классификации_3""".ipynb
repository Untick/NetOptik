# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/NetOptik/blob/Shironin-Igor-branch/Shironin%20Igor/3_%22%D1%81%D1%82%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0_%D0%B7%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BA%D0%BB%D0%B0%D1%81%D1%81%D0%B8%D1%84%D0%B8%D0%BA%D0%B0%D1%86%D0%B8%D0%B8_3%22%22%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import tensorflow as tf
# from tensorflow import keras

# %% [markdown]
# # Библиотеки

# %%
# Работа с массивами
import numpy as np
import random                             # Генерация случайных чисел
import pandas as pd
# Генератор аугментированных изображений
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Основа для создания последовательной модели
from tensorflow.keras.models import Sequential
# Основные слои
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
# Оптимизатор
from tensorflow.keras.optimizers import Adam
# Матрица ошибок классификатора
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# Подключение модуля для загрузки данных из облака
import gdown
# Инструменты для работы с файлами
import os
# Отрисовка графиков
import matplotlib.pyplot as plt
from PIL import Image, ImageEnhance       # Инструменты для работы с изображениями
import math                               # Математические функции
import  requests, zipfile
# !pip install GitPython
from sklearn.model_selection import train_test_split
# Рисование графиков в ячейках Colab
# %matplotlib inline
# Out:
# Collecting GitPython
#   Downloading GitPython-3.1.34-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.6/188.6 kB 2.4 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from GitPython)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.5 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, GitPython
# Successfully installed GitPython-3.1.34 gitdb-4.0.10 smmap-5.0.0

# %% [markdown]
# # Загрузка изображений

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# открываем доступ к файлу и получаем ссылку
# https://drive.google.com/file/d/1Kul4G02U2g18rmunwdelNaLOMde6tBNC/view?usp=sharing
f_1 = '1Kul4G02U2g18rmunwdelNaLOMde6tBNC'# нужна только эта часть ссылки
gdown.download(f'https://drive.google.com/uc?id={f_1}', None, quiet=True)
# Out:
# 'task3.zip'

# %%
# Разархивация датасета в директорию 'content/TOTAL_folder'
# !unzip -qo "task3.zip" -d /content/img
# Out:
# Втулки/:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/),
#          continuing with "central" filename version
# Втулки/ana-hickmann-ah1279-02a-s2-1 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/ana-hickmann-ah1279-02a-s2-1 (2).jpg),
#          continuing with "central" filename version
# Втулки/ana-hickmann-ah1279-02a-s2-2 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/ana-hickmann-ah1279-02a-s2-2 (1).jpg),
#          continuing with "central" filename version
# Втулки/andy-wolf-davis-cd-s2-1  (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/andy-wolf-davis-cd-s2-1  (2).jpg),
#          continuing with "central" filename version
# Втулки/andy-wolf-davis-cd-s2-1.jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/andy-wolf-davis-cd-s2-1.jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc209-c3-s2-1 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc209-c3-s2-1 (1).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc209-c3-s2-2 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc209-c3-s2-2 (2).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc284-c2-s2-1 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc284-c2-s2-1 (1).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc284-c2-s2-2 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc284-c2-s2-2 (2).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc285-c3-s2-1 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc285-c3-s2-1 (1).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc285-c3-s2-2 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc285-c3-s2-2 (2).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc286-c1-s2-1 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc286-c1-s2-1 (1).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc286-c1-s2-2 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc286-c1-s2-2 (2).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc286-c2-s2-1 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc286-c2-s2-1 (1).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc286-c2-s2-2 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc286-c2-s2-2 (2).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc289-c3-s2-1 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc289-c3-s2-1 (1).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc289-c3-s2-2 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc289-c3-s2-2 (2).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc290-c4-s2-1 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc290-c4-s2-1 (1).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc290-c4-s2-2 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc290-c4-s2-2 (2).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc291-c2-s2-1 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc291-c2-s2-1 (1).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc291-c2-s2-2 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc291-c2-s2-2 (2).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc294-c4-s2-1 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc294-c4-s2-1 (1).jpg),
#          continuing with "central" filename version
# Втулки/blancia-bc294-c4-s2-2 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/blancia-bc294-c4-s2-2 (2).jpg),
#          continuing with "central" filename version
# Втулки/cerruti-ce6554-02-s2-1 (3).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/cerruti-ce6554-02-s2-1 (3).jpg),
#          continuing with "central" filename version
# Втулки/cerruti-ce6554-02-s2-2 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/cerruti-ce6554-02-s2-2 (2).jpg),
#          continuing with "central" filename version
# Втулки/cerruti-ce6556-c2-s2-1 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/cerruti-ce6556-c2-s2-1 (2).jpg),
#          continuing with "central" filename version
# Втулки/cerruti-ce6556-c2-s2-2 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/cerruti-ce6556-c2-s2-2 (1).jpg),
#          continuing with "central" filename version
# Втулки/chopard-vchb51g-349y-s2-1 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/chopard-vchb51g-349y-s2-1 (1).jpg),
#          continuing with "central" filename version
# Втулки/chopard-vchb51g-349y-s2-2 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/chopard-vchb51g-349y-s2-2 (1).jpg),
#          continuing with "central" filename version
# Втулки/chopard-vchb71s-0s87-s2-1 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/chopard-vchb71s-0s87-s2-1 (2).jpg),
#          continuing with "central" filename version
# Втулки/chopard-vchb71s-0s87-s2-2 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/chopard-vchb71s-0s87-s2-2 (1).jpg),
#          continuing with "central" filename version
# Втулки/chopard-vchb97s-0300-s2-1 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/chopard-vchb97s-0300-s2-1 (2).jpg),
#          continuing with "central" filename version
# Втулки/chopard-vchb97s-0300-s2-2 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/chopard-vchb97s-0300-s2-2 (1).jpg),
#          continuing with "central" filename version
# Втулки/chopard-vchc35s-0300-s2-1 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/chopard-vchc35s-0300-s2-1 (2).jpg),
#          continuing with "central" filename version
# Втулки/chopard-vchc35s-0300-s2-2 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/chopard-vchc35s-0300-s2-2 (1).jpg),
#          continuing with "central" filename version
# Втулки/chopard-vchc37-0316-s2-1 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/chopard-vchc37-0316-s2-1 (2).jpg),
#          continuing with "central" filename version
# Втулки/chopard-vchc37-0316-s2-2 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/chopard-vchc37-0316-s2-2 (1).jpg),
#          continuing with "central" filename version
# Втулки/chopard-vchc39-0579-s2-1 (2).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/chopard-vchc39-0579-s2-1 (2).jpg),
#          continuing with "central" filename version
# Втулки/chopard-vchc39-0579-s2-2 (1).jpg:  mismatching "local" filename (╨Т╤В╤Г╨╗╨║╨╕/chopard-vch
s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-md379-7822-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-md379-s1625-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-md379-s1625-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-md379-s1625-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-md379-s1625-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-md429-s1625-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-md429-s1625-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-md429-s1625-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-md429-s1625-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-md523-ca967-s2-1 (51).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-md523-ca967-s2-1 (51).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-md523-ca967-s2-2 (50).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-md523-ca967-s2-2 (50).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-vy01-02-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-vy01-02-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-vy01-02-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-vy01-02-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-vy16-04-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-vy16-04-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-vy16-04-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-vy16-04-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-vy16-05-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-vy16-05-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-vy16-05-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-vy16-05-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-vy27-4-025-s2-1 (17).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-vy27-4-025-s2-1 (17).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-vy27-4-025-s2-2 (15).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-vy27-4-025-s2-2 (15).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-vy5-01-s2-1 (9).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-vy5-01-s2-1 (9).jpg),
#          continuing with "central" filename version
# Ободки/valentin-yudashkin-vy5-01-s2-2 (8).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/valentin-yudashkin-vy5-01-s2-2 (8).jpg),
#          continuing with "central" filename version
# Ободки/web-we5106-052-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5106-052-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/web-we5106-052-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5106-052-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/web-we5115-052-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5115-052-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/web-we5115-052-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5115-052-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/web-we5140-067-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5140-067-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/web-we5140-067-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5140-067-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/web-we5145-052-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5145-052-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/web-we5145-052-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5145-052-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/web-we5166-002-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5166-002-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/web-we5166-002-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5166-002-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/web-we5166-049-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5166-049-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/web-we5166-049-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5166-049-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/web-we5177-008-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5177-008-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/web-we5177-008-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5177-008-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/web-we5241-016-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5241-016-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/web-we5241-016-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5241-016-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/web-we5285-32a-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5285-32a-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/web-we5285-32a-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5285-32a-s2-2 (2).jpg),
#          continuing with "central" filename version
# Ободки/web-we5288-56a-s2-1 (3).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5288-56a-s2-1 (3).jpg),
#          continuing with "central" filename version
# Ободки/web-we5288-56a-s2-2 (2).jpg:  mismatching "local" filename (╨Ю╨▒╨╛╨┤╨║╨╕/web-we5288-56a-s2-2 (2).jpg),
#          continuing with "central" filename version

# %%
# !rm /content/img/Втулки/desktop.ini
# !rm /content/img/Леска/desktop.ini
# !rm /content/img/Ободки/desktop.ini

# %%
# Папка с папками картинок, рассортированных по категориям
IMAGE_PATH = '/content/img/'
os.listdir(IMAGE_PATH)
# Out:
# ['Втулки', 'Леска', 'Ободки']

# %% [markdown]
# # Cоздание списков путей к файлам и меток к ним

# %%
# Определение списка имен классов
CLASS_LIST = sorted(os.listdir(IMAGE_PATH)) # можно не сортировать CLASS_LIST = os.listdir(IMAGE_PATH)
# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)
# Проверка результата
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}')
# Out:
# Количество классов: 3, метки классов: ['Втулки', 'Леска', 'Ободки']

# %%
# Создание заготовки для изображений всех классов
fig, axs = plt.subplots(1, CLASS_COUNT, figsize=(25, 5))

# Для всех номеров классов:
for i in range(CLASS_COUNT):
    # Формирование пути к папке содержимого класса
    path = f'{IMAGE_PATH}{CLASS_LIST[i]}/'
    # Выбор случайного фото из i-го класса
    img_path = path + random.choice(os.listdir(path))
    # Отображение фотографий
    axs[i].set_title(CLASS_LIST[i])
    axs[i].imshow(Image.open(img_path))
    axs[i].axis('off')

# Отрисовка всего полотна
plt.show()

# %%
data_files = []                           # Cписок путей к файлам картинок
data_labels = []                          # Список меток классов, соответствующих файлам


for class_label in range(CLASS_COUNT):    # Для всех классов по порядку номеров (их меток)
    class_name = CLASS_LIST[class_label]  # Выборка имени класса из списка имен
    class_path = IMAGE_PATH + class_name  # Формирование полного пути к папке с изображениями класса
    class_files = os.listdir(class_path)  # Получение списка имен файлов с изображениями текущего класса
    print(f'Размер класса {class_name} составляет {len(class_files)} фото')

    # Добавление к общему списку всех файлов класса с добавлением родительского пути
    data_files += [f'{class_path}/{file_name}' for file_name in class_files]

    # Добавление к общему списку меток текущего класса - их ровно столько, сколько файлов в классе
    data_labels += [class_label] * len(class_files)
    print('Общий размер базы для обучения:', len(data_labels))
# Out:
# Размер класса Втулки составляет 410 фото
# Общий размер базы для обучения: 410
# Размер класса Леска составляет 502 фото
# Общий размер базы для обучения: 912
# Размер класса Ободки составляет 502 фото
# Общий размер базы для обучения: 1414

# %% [markdown]
# # просмотр фото

# %%
img  = Image.open(data_files[1300])
print(img.size)
print(data_labels[1300])
img
# Out:
# (900, 600)
# 2
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600>

# %% [markdown]
# # Получение списка файлов data_img c размерностью 128х64

# %%
IMG_WIDTH           = 128       # Ширина изображения для нейросети
IMG_HEIGHT          = 64      # Высота изображения для нейросети

# %%
data_img = []
for i in range(len(data_files)):
  img_old  = Image.open( data_files[i])
  img = img_old.resize((IMG_WIDTH ,IMG_HEIGHT ))
  data_img.append(img)

# %%
img1 = data_img[5]

# %%
img1
# Out:
# <PIL.Image.Image image mode=RGB size=128x64>

# %% [markdown]
# # Создание аугментированного списка изображений

# %%
# Сравнение двух изображений
def show_image_pair(img1, img2): #
    # Cоздание полотна для рисования двух изображений
    fig, axs = plt.subplots(1, 2, figsize=(4, 2))
    # Исходное изображение
    axs[0].imshow(img1)
    axs[0].axis('off')
    # Модифицированное изображение
    axs[1].imshow(img2)
    axs[1].axis('off')
    # Вывод изображений
    plt.show()

# %%
# подрезка изображения чтобы небыло черных углов
def rotated_rect(w,                       # Ширина изображения
                 h,                       # Высота изображения
                 angle                    # Угол поворота в градусах
                 ):
    angle = math.radians(angle)
    width_is_longer = w >= h
    side_long, side_short = (w,h) if width_is_longer else (h,w)

    sin_a, cos_a = abs(math.sin(angle)), abs(math.cos(angle))

    if side_short <= 2.*sin_a*cos_a*side_long or abs(sin_a-cos_a) < 1e-10:
        x = 0.5 * side_short
        wr, hr = (x/sin_a, x/cos_a) if width_is_longer else (x/cos_a, x/sin_a)
    else:
        cos_2a = cos_a*cos_a - sin_a*sin_a
        wr, hr = (w*cos_a - h*sin_a)/cos_2a, (h*cos_a - w*sin_a)/cos_2a

    return wr, hr # Ширина и Высота прямоугольника обрезки

# %%
 # функция поворота на случайный угол (в градусах) с учетом необходимой обрезки
 # + востановление размеров
def random_rot(x,      # Подаваемое изображение
               ang                        # Максимальный угол поворота
               ):
    # Случайное значение угла в диапазоне [-ang, ang]
  a = random.uniform(-1., 1.) * ang
    # Вращение картинки с расширением рамки
  r = x.rotate(a, expand=True)
    # Вычисление размеров прямоугольника обрезки максимальной площади
    # для размеров исходной картинки и угла поворота в градусах
  crop_w, crop_h = rotated_rect(x.width, x.height, a)
    # Обрезка повернутого изображения и возврат результата
  w, h = r.size
  y = r.crop(((w - crop_w)*0.5, (h - crop_h)*0.5,
                   (w + crop_w)*0.5, (h + crop_h)*0.5))
  y = y.resize((x.width,x.height))
  return y              # Полученное изображение

# %%
from PIL import ImageEnhance

# %%
def random_contrast(x,                    # Подаваемое изображение
                    level                 # Максимальное отклонение коэффициента контраста от нормы - число от 0. до 1.
                    ):
    enh = ImageEnhance.Contrast(x)        # Создание экземпляра класса Contrast
    factor = random.uniform(1. - level,
                            1. + level)   # Cлучайный коэффициент контраста из указанного интервала
    return enh.enhance(factor)            # Получаемое изображение с изменением коэффициента контраста

# %%
def random_brightness(x,                  # Подаваемое изображение
                      level               # Максимальное отклонение коэффициента яркости от нормы - число от 0. до 1.
                      ):
    enh = ImageEnhance.Brightness(x)      # Создание экземпляра класса Brightness
    factor = random.uniform(1. - level,
                            1. + level)   # Cлучайный коэффициент яркости из указанного интервала
    return enh.enhance(factor)             # Получаемое изображение с изменением коэффициента яркости

# %%
def  trans_img(img1) :
  img2 = img1.transpose(Image.FLIP_LEFT_RIGHT) # отражение
  return img2

# %%
ang = 10
level = 0.4

# %%
def aug (img, ang, level):
    # Cоздание списка модификаций
  mod_oper = [random_rot(img,ang),
                trans_img(img),
                random_contrast(img,level),
                random_brightness(img,level)]

    # Cлучайное количество изменений из списка; минимум одно изменение
  mod_count = random.randrange(len(mod_oper) + 1)

    # Случайный отбор индексов изменений в количестве mod_count без повторений
  mod_list = random.sample(range(len(mod_oper)), mod_count)

    # Применение модификаций по индексам из mod_list
  for mod_index in mod_list:
        img = mod_oper[mod_index]

    # Возврат результата
  return img

# %%
img1 = data_img[100]
img2 = aug(img1,ang, level)
show_image_pair(img1, img2)

# %%
# функция для получения списка из n аугментированых изображений + родное
# со списком одинаковых меток например '50.jpg'

def aug_list(img, n, mark):
  img_list = [img]
  a_list = [mark]
  for i in range(n):
    img_list += [aug(img,ang,level)]
    a_list.append(mark)
  return img_list , a_list

# %%
n = 5
a,b = aug_list(img1,n,5)
a[3]
# Out:
# <PIL.Image.Image image mode=RGB size=128x64>

# %%
fig, axs = plt.subplots(1, 6, figsize=(4, 2))

a,b  = aug_list(data_img[1000],5,data_labels[1000])
for i in range(6):
    # Исходное изображение
  axs[i].imshow(a[i])
  axs[i].axis('off')

#     # Вывод изображений
plt.show()
b
# Out:
# [2, 2, 2, 2, 2, 2]

# %%
def aug_list_n (img_list,mark_list, n) :
  data_x = []
  data_y = []
  for i in range(len(img_list )):
    list_img ,list_a = aug_list(img_list[i],n-1,mark_list[i])
    for j in range(len(list_img )):
       data_x.append(list_img[j])
       data_y.append(list_a[j])
  return data_x, data_y

# %%
data_x, data_y = aug_list_n (data_img,data_labels, n)

# %%
print(data_x[1000].size)
print(len(data_x))
data_x[1000:1005]
# Out:
# (128, 64)
# 7070
# [<PIL.Image.Image image mode=RGB size=128x64>,
#  <PIL.Image.Image image mode=RGB size=128x64>,
#  <PIL.Image.Image image mode=RGB size=128x64>,
#  <PIL.Image.Image image mode=RGB size=128x64>,
#  <PIL.Image.Image image mode=RGB size=128x64>]

# %%
print(len(data_y))
data_y[1000]
# Out:
# 7070
# 0

# %% [markdown]
# # Подготовка выборок

# %%
print(data_x[1000].size)

# Преобразовать список в массив
data_images = np.array([np.array(img) for img in data_x])/255

# Проверить размерность
print(data_images.shape)
# Out:
# (128, 64)
# (7070, 64, 128, 3)

# %%
# from tensorflow.keras.preprocessing import image
# data_images = []
# for i in range(len(data_files)):
#   # изменение размера и нормализация
#   img  = np.array(image.load_img(data_files[i], target_size=(128, 64)))/255
# # создание общего спика изображений
#   data_images +=[img]

# %%
print(data_images[600].shape)
print(data_y[600])
data_images[600]
# Out:
# (64, 128, 3)
# 0
# array([[[0.83137255, 0.82745098, 0.81960784],
#         [0.83529412, 0.83137255, 0.82352941],
#         [0.83529412, 0.83137255, 0.82352941],
#         ...,
#         [0.87058824, 0.87058824, 0.87058824],
#         [0.86666667, 0.86666667, 0.86666667],
#         [0.86666667, 0.8627451 , 0.86666667]],
#
#        [[0.83529412, 0.83137255, 0.82352941],
#         [0.83921569, 0.83529412, 0.82745098],
#         [0.84705882, 0.84313725, 0.83137255],
#         ...,
#         [0.87058824, 0.87058824, 0.87058824],
#         [0.87058824, 0.87058824, 0.87058824],
#         [0.87058824, 0.86666667, 0.87058824]],
#
#        [[0.83921569, 0.83529412, 0.81960784],
#         [0.84313725, 0.83921569, 0.82352941],
#         [0.85098039, 0.84705882, 0.83529412],
#         ...,
#         [0.8745098 , 0.8745098 , 0.8745098 ],
#         [0.87058824, 0.87058824, 0.87058824],
#         [0.87058824, 0.87058824, 0.87058824]],
#
#        ...,
#
#        [[0.90196078, 0.90196078, 0.90196078],
#         [0.90196078, 0.90196078, 0.90196078],
#         [0.90588235, 0.90980392, 0.90588235],
#         ...,
#         [0.9372549 , 0.93333333, 0.91764706],
#         [0.9372549 , 0.93333333, 0.91764706],
#         [0.9372549 , 0.93333333, 0.91764706]],
#
#        [[0.90588235, 0.90196078, 0.89803922],
#         [0.90588235, 0.90588235, 0.90196078],
#         [0.90588235, 0.90196078, 0.90196078],
#         ...,
#         [0.93333333, 0.92941176, 0.91764706],
#         [0.93333333, 0.92941176, 0.91372549],
#         [0.93333333, 0.92941176, 0.91372549]],
#
#        [[0.90588235, 0.90196078, 0.89411765],
#         [0.90588235, 0.90196078, 0.89411765],
#         [0.90588235, 0.90196078, 0.89411765],
#         ...,
#         [0.93333333, 0.92941176, 0.91372549],
#         [0.93333333, 0.92941176, 0.91372549],
#         [0.93333333, 0.92941176, 0.91372549]]])

# %%
data_images[1].shape
# Out:
# (64, 128, 3)

# %%
x_data = np.array(data_images)          # Перевод общего списка изображений в numpy-массив
y_data = np.array(data_y)            # Перевод общего списка меток класса в numpy-массив
print(f'Общий массив данных изображений следующей формы: {x_data.shape}')
print(f'Общий массив меток классов следующей формы: {y_data.shape}')
# Out:
# Общий массив данных изображений следующей формы: (7070, 64, 128, 3)
# Общий массив меток классов следующей формы: (7070,)

# %%
# Преобразование данных в формат one_hot_encoding
from tensorflow.keras.utils import to_categorical
y_data = to_categorical(y_data, 3)
y_data[5]
# Out:
# array([1., 0., 0.], dtype=float32)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, # ----------------- датасет с изображениям
                                                    y_data, # ----------------- датасет с метками
                                                    test_size = 0.1, # --- процент тестовых значений
                                                    shuffle=True, # ------ перемешивание
                                                    random_state=42) # ---

# %%
x_train, x_val, y_train, y_val = train_test_split(x_data, # ----------------- датасет с изображениям
                                                    y_data, # ----------------- датасет с метками
                                                    test_size = 0.2, # --- процент тестовых значений
                                                    shuffle=True, # ------ перемешивание
                                                    random_state=42) # ---
print(f'Общий массив данных изображений следующей формы: {x_train.shape}')
print(f'Общий массив меток классов следующей формы: {y_train.shape}')
print(f'Общий массив данных проверочных изображений следующей формы: {x_val.shape}')
print(f'Общий массив проверочных меток классов следующей формы: {y_val.shape}')
print(f'Общий массив тестовых данных  изображений следующей формы: {x_test.shape}')
print(f'Общий массив тестовых меток классов следующей формы: {y_test.shape}')
# Out:
# Общий массив данных изображений следующей формы: (5656, 64, 128, 3)
# Общий массив меток классов следующей формы: (5656, 3)
# Общий массив данных проверочных изображений следующей формы: (1414, 64, 128, 3)
# Общий массив проверочных меток классов следующей формы: (1414, 3)
# Общий массив тестовых данных  изображений следующей формы: (707, 64, 128, 3)
# Общий массив тестовых меток классов следующей формы: (707, 3)

# %% [markdown]
# # Cоздание и обучение модели

# %%
EPOCHS              = 150       # Число эпох обучения
BATCH_SIZE          = 24                    # Размер батча для обучения модели
OPTIMIZER           = Adam(0.0001)
CLASS_COUNT         = 3

IMG_CHANNELS        = 3

# %%
# Создание последовательной модели
model_conv = Sequential()

# Первый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH  , IMG_CHANNELS)))
model_conv.add(BatchNormalization())

# Второй сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))

# Третий сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())
model_conv.add(Dropout(0.2))

# Четвертый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Пятый сверточный слой
model_conv.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())

# Шестой сверточный слой
model_conv.add(Conv2D(1024, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Слой преобразования многомерных данных в одномерные
model_conv.add(Flatten())

# Промежуточный полносвязный слой
model_conv.add(Dense(2048, activation='relu'))

# Промежуточный полносвязный слой
model_conv.add(Dense(4096, activation='relu'))
# Выходной полносвязный слой с количеством нейронов по количесту классов
model_conv.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
    # Вывод сводки
model_conv.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 128, 256)      7168
#
#  batch_normalization (BatchN  (None, 64, 128, 256)     1024
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 64, 128, 256)      590080
#
#  max_pooling2d (MaxPooling2D  (None, 21, 42, 256)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 21, 42, 256)       590080
#
#  batch_normalization_1 (Batc  (None, 21, 42, 256)      1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 21, 42, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 21, 42, 256)       590080
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 14, 256)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 14, 256)        0
#
#  conv2d_4 (Conv2D)           (None, 7, 14, 512)        1180160
#
#  batch_normalization_2 (Batc  (None, 7, 14, 512)       2048
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 7, 14, 1024)       4719616
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 4, 1024)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 2, 4, 1024)        0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 2048)              16779264
#
#  dense_1 (Dense)             (None, 4096)              8392704
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 32,865,539
# Trainable params: 32,863,491
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
# from tensorflow.keras.models import load_model

# model = load_model("/content/drive/MyDrive/model/model_conv.h5")

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
# Создание обратного вызова EarlyStopping
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1)
checkpoint = ModelCheckpoint('/content/drive/MyDrive/model/' + 'best_model3.h5', monitor='val_accuracy',
                             save_best_only=True, mode='max', verbose=1)

# %%
model_conv.compile(optimizer=OPTIMIZER,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
 # Обучение модели с заданными параметрами
history = model_conv.fit( x_train,y_train,
                        epochs=EPOCHS  ,
                      batch_size=BATCH_SIZE,
                        validation_data=(x_val, y_val),callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9774
# Epoch 1: val_accuracy improved from -inf to 0.93281, saving model to /content/drive/MyDrive/model/best_model3.h5
# 236/236 [==============================] - 60s 238ms/step - loss: 0.0730 - accuracy: 0.9774 - val_loss: 0.1705 - val_accuracy: 0.9328
# Epoch 2/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.9825
# Epoch 2: val_accuracy improved from 0.93281 to 0.98161, saving model to /content/drive/MyDrive/model/best_model3.h5
# 236/236 [==============================] - 63s 266ms/step - loss: 0.0482 - accuracy: 0.9825 - val_loss: 0.0669 - val_accuracy: 0.9816
# Epoch 3/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0396 - accuracy: 0.9862
# Epoch 3: val_accuracy did not improve from 0.98161
# 236/236 [==============================] - 44s 188ms/step - loss: 0.0396 - accuracy: 0.9862 - val_loss: 0.1410 - val_accuracy: 0.9675
# Epoch 4/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9857
# Epoch 4: val_accuracy did not improve from 0.98161
# 236/236 [==============================] - 42s 179ms/step - loss: 0.0478 - accuracy: 0.9857 - val_loss: 0.3450 - val_accuracy: 0.8819
# Epoch 5/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9866
# Epoch 5: val_accuracy did not improve from 0.98161
# 236/236 [==============================] - 42s 180ms/step - loss: 0.0368 - accuracy: 0.9866 - val_loss: 0.0656 - val_accuracy: 0.9774
# Epoch 6/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9892
# Epoch 6: val_accuracy did not improve from 0.98161
# 236/236 [==============================] - 45s 192ms/step - loss: 0.0404 - accuracy: 0.9892 - val_loss: 0.1430 - val_accuracy: 0.9519
# Epoch 7/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9894
# Epoch 7: val_accuracy did not improve from 0.98161
# 236/236 [==============================] - 43s 181ms/step - loss: 0.0326 - accuracy: 0.9894 - val_loss: 0.0577 - val_accuracy: 0.9809
# Epoch 8/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9885
# Epoch 8: val_accuracy improved from 0.98161 to 0.98586, saving model to /content/drive/MyDrive/model/best_model3.h5
# 236/236 [==============================] - 74s 312ms/step - loss: 0.0354 - accuracy: 0.9885 - val_loss: 0.0373 - val_accuracy: 0.9859
# Epoch 9/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9912
# Epoch 9: val_accuracy did not improve from 0.98586
# 236/236 [==============================] - 45s 189ms/step - loss: 0.0364 - accuracy: 0.9912 - val_loss: 0.3679 - val_accuracy: 0.9272
# Epoch 10/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9913
# Epoch 10: val_accuracy improved from 0.98586 to 0.98798, saving model to /content/drive/MyDrive/model/best_model3.h5
# 236/236 [==============================] - 76s 321ms/step - loss: 0.0256 - accuracy: 0.9913 - val_loss: 0.0406 - val_accuracy: 0.9880
# Epoch 11/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9936
# Epoch 11: val_accuracy did not improve from 0.98798
# 236/236 [==============================] - 45s 190ms/step - loss: 0.0189 - accuracy: 0.9936 - val_loss: 0.6218 - val_accuracy: 0.9364
# Epoch 12/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9961
# Epoch 12: val_accuracy improved from 0.98798 to 0.99293, saving model to /content/drive/MyDrive/model/best_model3.h5
# 236/236 [==============================] - 77s 328ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.0259 - val_accuracy: 0.9929
# Epoch 13/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9970
# Epoch 13: val_accuracy did not improve from 0.99293
# 236/236 [==============================] - 45s 189ms/step - loss: 0.0118 - accuracy: 0.9970 - val_loss: 0.0675 - val_accuracy: 0.9866
# Epoch 14/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9954
# Epoch 14: val_accuracy did not improve from 0.99293
# 236/236 [==============================] - 46s 197ms/step - loss: 0.0125 - accuracy: 0.9954 - val_loss: 0.0820 - val_accuracy: 0.9752
# Epoch 15/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9949
# Epoch 15: val_accuracy did not improve from 0.99293
# 236/236 [==============================] - 44s 188ms/step - loss: 0.0188 - accuracy: 0.9949 - val_loss: 0.0571 - val_accuracy: 0.9830
# Epoch 16/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9931
# Epoch 16: val_accuracy did not improve from 0.99293
# 236/236 [==============================] - 46s 196ms/step - loss: 0.0224 - accuracy: 0.9931 - val_loss: 0.0639 - val_accuracy: 0.9823
# Epoch 17/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9950
# Epoch 17: val_accuracy did not improve from 0.99293
# 236/236 [==============================] - 44s 187ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 0.1295 - val_accuracy: 0.9703
# Epoch 18/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9924
# Epoch 18: val_accuracy did not improve from 0.99293
# 236/236 [==============================] - 44s 185ms/step - loss: 0.0265 - accuracy: 0.9924 - val_loss: 0.0284 - val_accuracy: 0.9901
# Epoch 19/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9940
# Epoch 19: val_accuracy did not improve from 0.99293
# 236/236 [==============================] - 44s 186ms/step - loss: 0.0223 - accuracy: 0.9940 - val_loss: 0.2675 - val_accuracy: 0.8932
# Epoch 20/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9972
# Epoch 20: val_accuracy did not improve from 0.99293
# 236/236 [==============================] - 46s 196ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.0273 - val_accuracy: 0.9908
# Epoch 21/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9970
# Epoch 21: val_accuracy did not improve from 0.99293
# 236/236 [==============================] - 46s 196ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0659 - val_accuracy: 0.9859
# Epoch 22/150
# 236/236 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9947
# Epoch 22: val_accuracy did not improve from 0.99293
# 236/236 [==============================] - 46s 196ms/step - loss: 0.0175 - accuracy: 0.9947 - val_loss: 0.0389 - val_accuracy: 0.9915
# Epoch 22: early stopping

# %%
#model.save("model_conv.h5")

# %%
# # /content/drive/MyDrive/model
# model_conv.save(f'/content/drive/MyDrive/model/model_conv2.h5')

# %%
# from tensorflow.keras.models import load_model

# loaded_model = load_model("model_conv.h5")

# %%
# Создание полотна для рисунка
plt.figure(1, figsize=(18, 5))

# Задание первой (левой) области для построения графиков
plt.subplot(1, 2, 1)
# Отрисовка графиков 'loss' и 'val_loss' из значений словаря store_learning.history
plt.plot(history.history['loss'],
         label='Значение ошибки на обучающем наборе')
plt.plot(history.history['val_loss'],
         label='Значение ошибки на проверочном наборе')
# Задание подписей осей
plt.xlabel('Эпоха обучения')
plt.ylabel('Значение ошибки')
plt.legend()

# Задание второй (правой) области для построения графиков
plt.subplot(1, 2, 2)
# Отрисовка графиков 'accuracy' и 'val_accuracy' из значений словаря store_learning.history
plt.plot(history.history['accuracy'],
         label='Доля верных ответов на обучающем наборе')
plt.plot(history.history['val_accuracy'],
         label='Доля верных ответов на проверочном наборе')
# Задание подписей осей
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()

# Фиксация графиков и рисование всей картинки
plt.show()

# %%
from tensorflow.keras.models import load_model

model_conv = load_model("/content/drive/MyDrive/model/best_model3.h5")

# %%
scores = model_conv.evaluate(x_test, y_test, verbose=1)
print(scores)
print('Доля верных ответов на тестовых данных, в процентах: {:7.4%}'.format(scores[1]))
# Out:
# 23/23 [==============================] - 1s 46ms/step - loss: 0.0373 - accuracy: 0.9901
# [0.03725515305995941, 0.9900990128517151]
# Доля верных ответов на тестовых данных, в процентах: 99.0099%
