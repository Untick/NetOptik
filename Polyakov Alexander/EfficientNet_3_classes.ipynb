# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/NetOptik/blob/Polyakov-Alexander-branch/Polyakov%20Alexander/EfficientNet_3_classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Подготовка

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_DIR = '/content/drive/MyDrive/AI/datasets/arches/train/'
BATCH_SIZE = 32
IMG_SIZE = (224, 224)

# %%
datagen_train = ImageDataGenerator(rescale=1./255, validation_split=0.2)

datagen_train = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,      # использовать 20% данных для валидации
    rotation_range=20,         # случайный поворот на ±20 градусов
    width_shift_range=0.2,     # случайный сдвиг по ширине на ±20%
    height_shift_range=0.2,    # случайный сдвиг по высоте на ±20%
    zoom_range=0.2,            # случайное увеличение/уменьшение на ±20%
    horizontal_flip=True,      # случайное отражение по горизонтали
    brightness_range=[0.8, 1.2] # изменение яркости от 80% до 120%
)


train_generator = datagen_train.flow_from_directory(
    DATA_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator = datagen_train.flow_from_directory(
    DATA_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 960 images belonging to 3 classes.
# Found 240 images belonging to 3 classes.

# %% [markdown]
# ### Сравнение моделей

# %%
from tensorflow.keras.applications import EfficientNetB0
import importlib

def get_efficientnet_model(version):
    module = importlib.import_module("tensorflow.keras.applications")
    class_name = f"EfficientNetB{version}"
    class_ = getattr(module, class_name)
    return class_(weights='imagenet', include_top=False)

# Пример использования:
model = get_efficientnet_model(0)
model
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step

# %%
def train_efficientnet(version, epochs=10):
    base_model = get_efficientnet_model(version)

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    predictions = Dense(3, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Отключаем обучение базовых слоев
    for layer in base_model.layers:
        layer.trainable = False

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    history = model.fit(
      train_generator,
      validation_data=val_generator,
      epochs=epochs
    )

    max_val_accuracy = max(history.history['val_accuracy'])
    return max_val_accuracy

# %%
results = {}

for i in range(8):
    val_acc = train_efficientnet(i, epochs=5)
    results[f"EfficientNetB{i}"] = val_acc
# Out:
# Epoch 1/5
# 30/30 [==============================] - 580s 19s/step - loss: 1.2509 - accuracy: 0.3323 - val_loss: 1.1056 - val_accuracy: 0.3333
# Epoch 2/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.1097 - accuracy: 0.3615 - val_loss: 1.1188 - val_accuracy: 0.3333
# Epoch 3/5
# 30/30 [==============================] - 31s 1s/step - loss: 1.1174 - accuracy: 0.3208 - val_loss: 1.1279 - val_accuracy: 0.3333
# Epoch 4/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.1325 - accuracy: 0.2969 - val_loss: 1.1100 - val_accuracy: 0.3333
# Epoch 5/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.1089 - accuracy: 0.3125 - val_loss: 1.1066 - val_accuracy: 0.3333
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27018416/27018416 [==============================] - 2s 0us/step
# Epoch 1/5
# 30/30 [==============================] - 43s 1s/step - loss: 1.2264 - accuracy: 0.3479 - val_loss: 1.1029 - val_accuracy: 0.4042
# Epoch 2/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.1152 - accuracy: 0.3594 - val_loss: 1.0996 - val_accuracy: 0.3958
# Epoch 3/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.1152 - accuracy: 0.3719 - val_loss: 1.1986 - val_accuracy: 0.3333
# Epoch 4/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.1075 - accuracy: 0.3583 - val_loss: 1.0844 - val_accuracy: 0.3500
# Epoch 5/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.0845 - accuracy: 0.4010 - val_loss: 1.0876 - val_accuracy: 0.3542
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31790344/31790344 [==============================] - 2s 0us/step
# Epoch 1/5
# 30/30 [==============================] - 42s 1s/step - loss: 1.1934 - accuracy: 0.3313 - val_loss: 1.0934 - val_accuracy: 0.3333
# Epoch 2/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.1052 - accuracy: 0.3490 - val_loss: 1.1093 - val_accuracy: 0.3542
# Epoch 3/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.0980 - accuracy: 0.3802 - val_loss: 1.0804 - val_accuracy: 0.4667
# Epoch 4/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.0935 - accuracy: 0.3812 - val_loss: 1.0703 - val_accuracy: 0.4083
# Epoch 5/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.0815 - accuracy: 0.4031 - val_loss: 1.0906 - val_accuracy: 0.4167
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 [==============================] - 3s 0us/step
# Epoch 1/5
# 30/30 [==============================] - 44s 1s/step - loss: 1.1713 - accuracy: 0.3875 - val_loss: 1.0390 - val_accuracy: 0.3542
# Epoch 2/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.0361 - accuracy: 0.4448 - val_loss: 1.0581 - val_accuracy: 0.3750
# Epoch 3/5
# 30/30 [==============================] - 31s 1s/step - loss: 1.0628 - accuracy: 0.4219 - val_loss: 1.1335 - val_accuracy: 0.3917
# Epoch 4/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.0892 - accuracy: 0.4156 - val_loss: 1.0365 - val_accuracy: 0.3875
# Epoch 5/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.0432 - accuracy: 0.4396 - val_loss: 0.9979 - val_accuracy: 0.5083
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 [==============================] - 4s 0us/step
# Epoch 1/5
# 30/30 [==============================] - 47s 1s/step - loss: 1.2225 - accuracy: 0.3729 - val_loss: 1.1136 - val_accuracy: 0.3333
# Epoch 2/5
# 30/30 [==============================] - 31s 1s/step - loss: 1.0698 - accuracy: 0.3927 - val_loss: 1.0379 - val_accuracy: 0.4750
# Epoch 3/5
# 30/30 [==============================] - 31s 1s/step - loss: 1.0700 - accuracy: 0.3854 - val_loss: 1.0502 - val_accuracy: 0.3583
# Epoch 4/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.0763 - accuracy: 0.3865 - val_loss: 1.0523 - val_accuracy: 0.3458
# Epoch 5/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.0363 - accuracy: 0.4437 - val_loss: 1.0176 - val_accuracy: 0.4833
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 [==============================] - 6s 0us/step
# Epoch 1/5
# 30/30 [==============================] - 51s 1s/step - loss: 1.2611 - accuracy: 0.4156 - val_loss: 0.9937 - val_accuracy: 0.4833
# Epoch 2/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.0020 - accuracy: 0.4750 - val_loss: 0.9904 - val_accuracy: 0.4500
# Epoch 3/5
# 30/30 [==============================] - 31s 1s/step - loss: 1.0225 - accuracy: 0.4833 - val_loss: 0.9635 - val_accuracy: 0.5125
# Epoch 4/5
# 30/30 [==============================] - 30s 1s/step - loss: 0.9607 - accuracy: 0.5010 - val_loss: 0.9274 - val_accuracy: 0.5333
# Epoch 5/5
# 30/30 [==============================] - 30s 1s/step - loss: 0.9742 - accuracy: 0.4938 - val_loss: 0.9640 - val_accuracy: 0.5292
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb6_notop.h5
# 165234480/165234480 [==============================] - 7s 0us/step
# Epoch 1/5
# 30/30 [==============================] - 53s 1s/step - loss: 1.2465 - accuracy: 0.3802 - val_loss: 1.0356 - val_accuracy: 0.5167
# Epoch 2/5
# 30/30 [==============================] - 30s 1s/step - loss: 0.9938 - accuracy: 0.4729 - val_loss: 1.0562 - val_accuracy: 0.3833
# Epoch 3/5
# 30/30 [==============================] - 31s 1s/step - loss: 0.9880 - accuracy: 0.4823 - val_loss: 0.9761 - val_accuracy: 0.5292
# Epoch 4/5
# 30/30 [==============================] - 31s 1s/step - loss: 0.9372 - accuracy: 0.5271 - val_loss: 0.9236 - val_accuracy: 0.5542
# Epoch 5/5
# 30/30 [==============================] - 30s 1s/step - loss: 0.9365 - accuracy: 0.5135 - val_loss: 0.9013 - val_accuracy: 0.5500
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 [==============================] - 15s 0us/step
# Epoch 1/5
# 30/30 [==============================] - 58s 1s/step - loss: 1.3652 - accuracy: 0.3313 - val_loss: 1.1068 - val_accuracy: 0.3333
# Epoch 2/5
# 30/30 [==============================] - 31s 1s/step - loss: 1.1147 - accuracy: 0.3521 - val_loss: 1.0967 - val_accuracy: 0.3708
# Epoch 3/5
# 30/30 [==============================] - 31s 1s/step - loss: 1.1180 - accuracy: 0.3542 - val_loss: 1.0928 - val_accuracy: 0.4500
# Epoch 4/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.1052 - accuracy: 0.3542 - val_loss: 1.0928 - val_accuracy: 0.3542
# Epoch 5/5
# 30/30 [==============================] - 30s 1s/step - loss: 1.0991 - accuracy: 0.3552 - val_loss: 1.0665 - val_accuracy: 0.3917

# %%
import pandas as pd

df = pd.DataFrame(list(results.items()), columns=['Model', 'Validation Accuracy'])
print(df)
# Out:
#             Model  Validation Accuracy
# 0  EfficientNetB0             0.333333
# 1  EfficientNetB1             0.404167
# 2  EfficientNetB2             0.466667
# 3  EfficientNetB3             0.508333
# 4  EfficientNetB4             0.483333
# 5  EfficientNetB5             0.533333
# 6  EfficientNetB6             0.554167
# 7  EfficientNetB7             0.450000

# %% [markdown]
# ### Обучение лучшей модели

# %%
best_model_dir = '/content/drive/MyDrive/AI/datasets/arches/best_models/'

# %%
base_model = EfficientNetB3(weights='imagenet', include_top=False)

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(3, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Dissable train base layers
# for layer in base_model.layers:
#     layer.trainable = False

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
checkpoint_callback = ModelCheckpoint(
    best_model_dir + 'best_model_EfficientNetB3_val_accuracy_scratch_1.h5',
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max'
)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=150,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/150
# 30/30 [==============================] - ETA: 0s - loss: 0.4637 - accuracy: 0.8406
# Epoch 1: val_accuracy improved from -inf to 0.33333, saving model to /content/drive/MyDrive/AI/datasets/arches/best_models/best_model_EfficientNetB3_val_accuracy_scratch.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 30/30 [==============================] - 96s 1s/step - loss: 0.4637 - accuracy: 0.8406 - val_loss: 2.2871 - val_accuracy: 0.3333
# Epoch 2/150
# 30/30 [==============================] - ETA: 0s - loss: 0.2475 - accuracy: 0.9250
# Epoch 2: val_accuracy did not improve from 0.33333
# 30/30 [==============================] - 32s 1s/step - loss: 0.2475 - accuracy: 0.9250 - val_loss: 2.9246 - val_accuracy: 0.3333
# Epoch 3/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9521
# Epoch 3: val_accuracy did not improve from 0.33333
# 30/30 [==============================] - 30s 1s/step - loss: 0.1490 - accuracy: 0.9521 - val_loss: 3.2428 - val_accuracy: 0.3333
# Epoch 4/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9510
# Epoch 4: val_accuracy did not improve from 0.33333
# 30/30 [==============================] - 31s 1s/step - loss: 0.1609 - accuracy: 0.9510 - val_loss: 3.5844 - val_accuracy: 0.3333
# Epoch 5/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9646
# Epoch 5: val_accuracy improved from 0.33333 to 0.37917, saving model to /content/drive/MyDrive/AI/datasets/arches/best_models/best_model_EfficientNetB3_val_accuracy_scratch.h5
# 30/30 [==============================] - 34s 1s/step - loss: 0.1137 - accuracy: 0.9646 - val_loss: 2.4328 - val_accuracy: 0.3792
# Epoch 6/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.9573
# Epoch 6: val_accuracy did not improve from 0.37917
# 30/30 [==============================] - 31s 1s/step - loss: 0.1381 - accuracy: 0.9573 - val_loss: 1.8298 - val_accuracy: 0.2750
# Epoch 7/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.9802
# Epoch 7: val_accuracy did not improve from 0.37917
# 30/30 [==============================] - 31s 1s/step - loss: 0.0615 - accuracy: 0.9802 - val_loss: 1.9261 - val_accuracy: 0.3333
# Epoch 8/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1602 - accuracy: 0.9490
# Epoch 8: val_accuracy did not improve from 0.37917
# 30/30 [==============================] - 30s 1s/step - loss: 0.1602 - accuracy: 0.9490 - val_loss: 3.9316 - val_accuracy: 0.3333
# Epoch 9/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9812
# Epoch 9: val_accuracy did not improve from 0.37917
# 30/30 [==============================] - 31s 1s/step - loss: 0.0636 - accuracy: 0.9812 - val_loss: 3.8506 - val_accuracy: 0.3500
# Epoch 10/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9740
# Epoch 10: val_accuracy improved from 0.37917 to 0.73333, saving model to /content/drive/MyDrive/AI/datasets/arches/best_models/best_model_EfficientNetB3_val_accuracy_scratch.h5
# 30/30 [==============================] - 34s 1s/step - loss: 0.0624 - accuracy: 0.9740 - val_loss: 1.2194 - val_accuracy: 0.7333
# Epoch 11/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9854
# Epoch 11: val_accuracy improved from 0.73333 to 0.85833, saving model to /content/drive/MyDrive/AI/datasets/arches/best_models/best_model_EfficientNetB3_val_accuracy_scratch.h5
# 30/30 [==============================] - 34s 1s/step - loss: 0.0513 - accuracy: 0.9854 - val_loss: 0.6866 - val_accuracy: 0.8583
# Epoch 12/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9833
# Epoch 12: val_accuracy did not improve from 0.85833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0499 - accuracy: 0.9833 - val_loss: 0.6779 - val_accuracy: 0.8500
# Epoch 13/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9771
# Epoch 13: val_accuracy did not improve from 0.85833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0470 - accuracy: 0.9771 - val_loss: 2.0084 - val_accuracy: 0.2833
# Epoch 14/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9771
# Epoch 14: val_accuracy did not improve from 0.85833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0736 - accuracy: 0.9771 - val_loss: 2.1057 - val_accuracy: 0.3292
# Epoch 15/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9802
# Epoch 15: val_accuracy did not improve from 0.85833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0650 - accuracy: 0.9802 - val_loss: 1.2425 - val_accuracy: 0.3292
# Epoch 16/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9833
# Epoch 16: val_accuracy did not improve from 0.85833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0575 - accuracy: 0.9833 - val_loss: 2.1959 - val_accuracy: 0.3333
# Epoch 17/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9844
# Epoch 17: val_accuracy did not improve from 0.85833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0544 - accuracy: 0.9844 - val_loss: 3.2189 - val_accuracy: 0.3333
# Epoch 18/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9854
# Epoch 18: val_accuracy did not improve from 0.85833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0411 - accuracy: 0.9854 - val_loss: 1.6915 - val_accuracy: 0.4708
# Epoch 19/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9854
# Epoch 19: val_accuracy did not improve from 0.85833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0579 - accuracy: 0.9854 - val_loss: 1.8049 - val_accuracy: 0.3333
# Epoch 20/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 0.9844
# Epoch 20: val_accuracy did not improve from 0.85833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0449 - accuracy: 0.9844 - val_loss: 1.7316 - val_accuracy: 0.6375
# Epoch 21/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9896
# Epoch 21: val_accuracy improved from 0.85833 to 0.92500, saving model to /content/drive/MyDrive/AI/datasets/arches/best_models/best_model_EfficientNetB3_val_accuracy_scratch.h5
# 30/30 [==============================] - 34s 1s/step - loss: 0.0458 - accuracy: 0.9896 - val_loss: 0.2233 - val_accuracy: 0.9250
# Epoch 22/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9875
# Epoch 22: val_accuracy did not improve from 0.92500
# 30/30 [==============================] - 31s 1s/step - loss: 0.0333 - accuracy: 0.9875 - val_loss: 0.8196 - val_accuracy: 0.7292
# Epoch 23/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9865
# Epoch 23: val_accuracy did not improve from 0.92500
# 30/30 [==============================] - 30s 1s/step - loss: 0.0546 - accuracy: 0.9865 - val_loss: 1.8672 - val_accuracy: 0.3375
# Epoch 24/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9875
# Epoch 24: val_accuracy did not improve from 0.92500
# 30/30 [==============================] - 30s 1s/step - loss: 0.0236 - accuracy: 0.9875 - val_loss: 1.7467 - val_accuracy: 0.3500
# Epoch 25/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9865
# Epoch 25: val_accuracy did not improve from 0.92500
# 30/30 [==============================] - 31s 1s/step - loss: 0.0583 - accuracy: 0.9865 - val_loss: 2.1347 - val_accuracy: 0.3333
# Epoch 26/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0318 - accuracy: 0.9948
# Epoch 26: val_accuracy did not improve from 0.92500
# 30/30 [==============================] - 30s 997ms/step - loss: 0.0318 - accuracy: 0.9948 - val_loss: 2.0986 - val_accuracy: 0.3333
# Epoch 27/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0485 - accuracy: 0.9865
# Epoch 27: val_accuracy did not improve from 0.92500
# 30/30 [==============================] - 30s 1s/step - loss: 0.0485 - accuracy: 0.9865 - val_loss: 5.3293 - val_accuracy: 0.3333
# Epoch 28/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9844
# Epoch 28: val_accuracy did not improve from 0.92500
# 30/30 [==============================] - 30s 1s/step - loss: 0.0490 - accuracy: 0.9844 - val_loss: 1.5641 - val_accuracy: 0.3333
# Epoch 29/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9875
# Epoch 29: val_accuracy did not improve from 0.92500
# 30/30 [==============================] - 30s 1s/step - loss: 0.0561 - accuracy: 0.9875 - val_loss: 0.3505 - val_accuracy: 0.8917
# Epoch 30/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9948
# Epoch 30: val_accuracy improved from 0.92500 to 0.95833, saving model to /content/drive/MyDrive/AI/datasets/arches/best_models/best_model_EfficientNetB3_val_accuracy_scratch.h5
# 30/30 [==============================] - 33s 1s/step - loss: 0.0250 - accuracy: 0.9948 - val_loss: 0.1858 - val_accuracy: 0.9583
# Epoch 31/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9927
# Epoch 31: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0225 - accuracy: 0.9927 - val_loss: 0.2245 - val_accuracy: 0.9250
# Epoch 32/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9854
# Epoch 32: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0371 - accuracy: 0.9854 - val_loss: 2.1339 - val_accuracy: 0.4208
# Epoch 33/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9781
# Epoch 33: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0536 - accuracy: 0.9781 - val_loss: 0.2587 - val_accuracy: 0.9417
# Epoch 34/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0679 - accuracy: 0.9833
# Epoch 34: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0679 - accuracy: 0.9833 - val_loss: 0.6534 - val_accuracy: 0.8333
# Epoch 35/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9865
# Epoch 35: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0434 - accuracy: 0.9865 - val_loss: 2.7267 - val_accuracy: 0.3583
# Epoch 36/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0439 - accuracy: 0.9885
# Epoch 36: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0439 - accuracy: 0.9885 - val_loss: 1.7605 - val_accuracy: 0.6208
# Epoch 37/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9885
# Epoch 37: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0258 - accuracy: 0.9885 - val_loss: 1.7375 - val_accuracy: 0.5500
# Epoch 38/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9906
# Epoch 38: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0253 - accuracy: 0.9906 - val_loss: 3.9872 - val_accuracy: 0.3958
# Epoch 39/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.9729
# Epoch 39: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 31s 1s/step - loss: 0.1212 - accuracy: 0.9729 - val_loss: 1.9631 - val_accuracy: 0.3500
# Epoch 40/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9719
# Epoch 40: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0947 - accuracy: 0.9719 - val_loss: 4.5230 - val_accuracy: 0.2958
# Epoch 41/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9896
# Epoch 41: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0466 - accuracy: 0.9896 - val_loss: 32.1396 - val_accuracy: 0.3333
# Epoch 42/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9844
# Epoch 42: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0535 - accuracy: 0.9844 - val_loss: 2.3035 - val_accuracy: 0.3792
# Epoch 43/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9906
# Epoch 43: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0210 - accuracy: 0.9906 - val_loss: 10.0593 - val_accuracy: 0.3333
# Epoch 44/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9844
# Epoch 44: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0496 - accuracy: 0.9844 - val_loss: 8.7017 - val_accuracy: 0.3333
# Epoch 45/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9792
# Epoch 45: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0542 - accuracy: 0.9792 - val_loss: 91.0037 - val_accuracy: 0.3333
# Epoch 46/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9906
# Epoch 46: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0249 - accuracy: 0.9906 - val_loss: 3.3716 - val_accuracy: 0.3333
# Epoch 47/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9896
# Epoch 47: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0260 - accuracy: 0.9896 - val_loss: 1.7162 - val_accuracy: 0.3333
# Epoch 48/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9948
# Epoch 48: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 2.8250 - val_accuracy: 0.3500
# Epoch 49/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9927
# Epoch 49: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0195 - accuracy: 0.9927 - val_loss: 1.8197 - val_accuracy: 0.4917
# Epoch 50/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0386 - accuracy: 0.9875
# Epoch 50: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0386 - accuracy: 0.9875 - val_loss: 3.1985 - val_accuracy: 0.3875
# Epoch 51/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9896
# Epoch 51: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0240 - accuracy: 0.9896 - val_loss: 3.1177 - val_accuracy: 0.3500
# Epoch 52/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9948
# Epoch 52: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0078 - accuracy: 0.9948 - val_loss: 3.8214 - val_accuracy: 0.3167
# Epoch 53/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9969
# Epoch 53: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 2.1724 - val_accuracy: 0.3167
# Epoch 54/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9948
# Epoch 54: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0101 - accuracy: 0.9948 - val_loss: 4.5540 - val_accuracy: 0.3500
# Epoch 55/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9896
# Epoch 55: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0255 - accuracy: 0.9896 - val_loss: 1.9103 - val_accuracy: 0.3333
# Epoch 56/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9865
# Epoch 56: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0299 - accuracy: 0.9865 - val_loss: 2.1690 - val_accuracy: 0.3250
# Epoch 57/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9906
# Epoch 57: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0287 - accuracy: 0.9906 - val_loss: 2.7053 - val_accuracy: 0.3333
# Epoch 58/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9896
# Epoch 58: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0198 - accuracy: 0.9896 - val_loss: 0.3954 - val_accuracy: 0.9042
# Epoch 59/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9854
# Epoch 59: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0403 - accuracy: 0.9854 - val_loss: 1.4384 - val_accuracy: 0.3833
# Epoch 60/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9937
# Epoch 60: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0164 - accuracy: 0.9937 - val_loss: 1.7916 - val_accuracy: 0.3667
# Epoch 61/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9969
# Epoch 61: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 31s 1s/step - loss: 0.0057 - accuracy: 0.9969 - val_loss: 1.7972 - val_accuracy: 0.5292
# Epoch 62/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9948
# Epoch 62: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0065 - accuracy: 0.9948 - val_loss: 0.2680 - val_accuracy: 0.9333
# Epoch 63/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9958
# Epoch 63: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0071 - accuracy: 0.9958 - val_loss: 4.0954 - val_accuracy: 0.5833
# Epoch 64/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9917
# Epoch 64: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0164 - accuracy: 0.9917 - val_loss: 0.6211 - val_accuracy: 0.8792
# Epoch 65/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9948
# Epoch 65: val_accuracy did not improve from 0.95833
# 30/30 [==============================] - 30s 1s/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.5132 - val_accuracy: 0.8292
# Epoch 66/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9937
# Epoch 66: val_accuracy improved from 0.95833 to 0.96667, saving model to /content/drive/MyDrive/AI/datasets/arches/best_models/best_model_EfficientNetB3_val_accuracy_scratch.h5
# 30/30 [==============================] - 34s 1s/step - loss: 0.0130 - accuracy: 0.9937 - val_loss: 0.2852 - val_accuracy: 0.9667
# Epoch 67/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9885
# Epoch 67: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 30s 1s/step - loss: 0.0425 - accuracy: 0.9885 - val_loss: 0.2720 - val_accuracy: 0.9625
# Epoch 68/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9927
# Epoch 68: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 30s 1s/step - loss: 0.0170 - accuracy: 0.9927 - val_loss: 142.2349 - val_accuracy: 0.3333
# Epoch 69/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9917
# Epoch 69: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 30s 1s/step - loss: 0.0125 - accuracy: 0.9917 - val_loss: 92.9438 - val_accuracy: 0.3333
# Epoch 70/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9937
# Epoch 70: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 31s 1s/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 2.0795 - val_accuracy: 0.3625
# Epoch 71/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9927
# Epoch 71: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 31s 1s/step - loss: 0.0320 - accuracy: 0.9927 - val_loss: 1.5941 - val_accuracy: 0.4125
# Epoch 72/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9833
# Epoch 72: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 30s 1s/step - loss: 0.0543 - accuracy: 0.9833 - val_loss: 5.2826 - val_accuracy: 0.3083
# Epoch 73/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9854
# Epoch 73: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 31s 1s/step - loss: 0.0459 - accuracy: 0.9854 - val_loss: 5.9558 - val_accuracy: 0.3417
# Epoch 74/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9948
# Epoch 74: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 31s 1s/step - loss: 0.0262 - accuracy: 0.9948 - val_loss: 31.0427 - val_accuracy: 0.3500
# Epoch 75/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9865
# Epoch 75: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 31s 1s/step - loss: 0.0598 - accuracy: 0.9865 - val_loss: 6.4392 - val_accuracy: 0.4500
# Epoch 76/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9750
# Epoch 76: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 30s 1s/step - loss: 0.0730 - accuracy: 0.9750 - val_loss: 2.7182 - val_accuracy: 0.3500
# Epoch 77/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9875
# Epoch 77: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 30s 1s/step - loss: 0.0541 - accuracy: 0.9875 - val_loss: 252.1834 - val_accuracy: 0.3417
# Epoch 78/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9865
# Epoch 78: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 30s 1s/step - loss: 0.0444 - accuracy: 0.9865 - val_loss: 549.3591 - val_accuracy: 0.3333
# Epoch 79/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9823
# Epoch 79: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 31s 1s/step - loss: 0.0432 - accuracy: 0.9823 - val_loss: 12.1321 - val_accuracy: 0.3208
# Epoch 80/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9906
# Epoch 80: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 31s 1s/step - loss: 0.0247 - accuracy: 0.9906 - val_loss: 5.6137 - val_accuracy: 0.4625
# Epoch 81/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9865
# Epoch 81: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 30s 1s/step - loss: 0.0317 - accuracy: 0.9865 - val_loss: 1.3541 - val_accuracy: 0.7208
# Epoch 82/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9896
# Epoch 82: val_accuracy did not improve from 0.96667
# 30/30 [==============================] - 31s 1s/step - loss: 0.0360 - accuracy: 0.9896 - val_loss: 221.4612 - val_accuracy: 0.3333
# Epoch 83/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9948
# Epoch 83: val_accuracy improved from 0.96667 to 0.97083, saving model to /content/drive/MyDrive/AI/datasets/arches/best_models/best_model_EfficientNetB3_val_accuracy_scratch.h5
# 30/30 [==============================] - 34s 1s/step - loss: 0.0108 - accuracy: 0.9948 - val_loss: 0.2109 - val_accuracy: 0.9708
# Epoch 84/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9854
# Epoch 84: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0587 - accuracy: 0.9854 - val_loss: 3.8269 - val_accuracy: 0.3500
# Epoch 85/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9802
# Epoch 85: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0423 - accuracy: 0.9802 - val_loss: 6.9498 - val_accuracy: 0.3042
# Epoch 86/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9844
# Epoch 86: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0432 - accuracy: 0.9844 - val_loss: 0.3061 - val_accuracy: 0.9083
# Epoch 87/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9833
# Epoch 87: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0567 - accuracy: 0.9833 - val_loss: 2.1746 - val_accuracy: 0.4875
# Epoch 88/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9906
# Epoch 88: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0248 - accuracy: 0.9906 - val_loss: 0.4993 - val_accuracy: 0.9000
# Epoch 89/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9948
# Epoch 89: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0166 - accuracy: 0.9948 - val_loss: 3.2216 - val_accuracy: 0.3958
# Epoch 90/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9937
# Epoch 90: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0100 - accuracy: 0.9937 - val_loss: 9.4177 - val_accuracy: 0.3292
# Epoch 91/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9969
# Epoch 91: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0280 - accuracy: 0.9969 - val_loss: 3.7102 - val_accuracy: 0.3458
# Epoch 92/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9948
# Epoch 92: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0255 - accuracy: 0.9948 - val_loss: 0.8063 - val_accuracy: 0.7750
# Epoch 93/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9969
# Epoch 93: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0123 - accuracy: 0.9969 - val_loss: 0.6572 - val_accuracy: 0.8500
# Epoch 94/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9969
# Epoch 94: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0152 - accuracy: 0.9969 - val_loss: 0.8063 - val_accuracy: 0.8458
# Epoch 95/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9969
# Epoch 95: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0111 - accuracy: 0.9969 - val_loss: 0.6452 - val_accuracy: 0.8458
# Epoch 96/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9917
# Epoch 96: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0190 - accuracy: 0.9917 - val_loss: 0.5256 - val_accuracy: 0.8000
# Epoch 97/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9896
# Epoch 97: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0238 - accuracy: 0.9896 - val_loss: 0.4743 - val_accuracy: 0.8792
# Epoch 98/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9927
# Epoch 98: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0208 - accuracy: 0.9927 - val_loss: 0.1632 - val_accuracy: 0.9625
# Epoch 99/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9896
# Epoch 99: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0254 - accuracy: 0.9896 - val_loss: 14.3551 - val_accuracy: 0.3333
# Epoch 100/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9969
# Epoch 100: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0146 - accuracy: 0.9969 - val_loss: 521.0246 - val_accuracy: 0.3333
# Epoch 101/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9958
# Epoch 101: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0113 - accuracy: 0.9958 - val_loss: 13.8438 - val_accuracy: 0.3333
# Epoch 102/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9969
# Epoch 102: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 3.4975 - val_accuracy: 0.3333
# Epoch 103/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9917
# Epoch 103: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0228 - accuracy: 0.9917 - val_loss: 0.2522 - val_accuracy: 0.9250
# Epoch 104/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9948
# Epoch 104: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0194 - accuracy: 0.9948 - val_loss: 3.4385 - val_accuracy: 0.3875
# Epoch 105/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9969
# Epoch 105: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0126 - accuracy: 0.9969 - val_loss: 2.8698 - val_accuracy: 0.4125
# Epoch 106/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9948
# Epoch 106: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0148 - accuracy: 0.9948 - val_loss: 4.2571 - val_accuracy: 0.3333
# Epoch 107/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9937
# Epoch 107: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0140 - accuracy: 0.9937 - val_loss: 5.7143 - val_accuracy: 0.3333
# Epoch 108/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9958
# Epoch 108: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0155 - accuracy: 0.9958 - val_loss: 3.3703 - val_accuracy: 0.3417
# Epoch 109/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9948
# Epoch 109: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0115 - accuracy: 0.9948 - val_loss: 1.2890 - val_accuracy: 0.6458
# Epoch 110/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9948
# Epoch 110: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0078 - accuracy: 0.9948 - val_loss: 3.6484 - val_accuracy: 0.3292
# Epoch 111/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9937
# Epoch 111: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0078 - accuracy: 0.9937 - val_loss: 128.3209 - val_accuracy: 0.3333
# Epoch 112/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9979
# Epoch 112: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0048 - accuracy: 0.9979 - val_loss: 3.7788 - val_accuracy: 0.3375
# Epoch 113/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9948
# Epoch 113: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0108 - accuracy: 0.9948 - val_loss: 215.0810 - val_accuracy: 0.3333
# Epoch 114/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9937
# Epoch 114: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0160 - accuracy: 0.9937 - val_loss: 349.1639 - val_accuracy: 0.3333
# Epoch 115/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9948
# Epoch 115: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0088 - accuracy: 0.9948 - val_loss: 2.1702 - val_accuracy: 0.5083
# Epoch 116/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9875
# Epoch 116: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0466 - accuracy: 0.9875 - val_loss: 2.2295 - val_accuracy: 0.3625
# Epoch 117/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9927
# Epoch 117: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0232 - accuracy: 0.9927 - val_loss: 25.5767 - val_accuracy: 0.3333
# Epoch 118/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9917
# Epoch 118: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0211 - accuracy: 0.9917 - val_loss: 1.3781 - val_accuracy: 0.5917
# Epoch 119/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9896
# Epoch 119: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0273 - accuracy: 0.9896 - val_loss: 1.0334 - val_accuracy: 0.5417
# Epoch 120/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9854
# Epoch 120: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0208 - accuracy: 0.9854 - val_loss: 1.5077 - val_accuracy: 0.5875
# Epoch 121/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9937
# Epoch 121: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0139 - accuracy: 0.9937 - val_loss: 7.5122 - val_accuracy: 0.3375
# Epoch 122/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9917
# Epoch 122: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0486 - accuracy: 0.9917 - val_loss: 264.1432 - val_accuracy: 0.3292
# Epoch 123/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9812
# Epoch 123: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0397 - accuracy: 0.9812 - val_loss: 1258.0208 - val_accuracy: 0.3333
# Epoch 124/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9917
# Epoch 124: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0246 - accuracy: 0.9917 - val_loss: 18.3721 - val_accuracy: 0.3333
# Epoch 125/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9937
# Epoch 125: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0118 - accuracy: 0.9937 - val_loss: 11.2787 - val_accuracy: 0.3333
# Epoch 126/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9896
# Epoch 126: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0198 - accuracy: 0.9896 - val_loss: 176.8450 - val_accuracy: 0.3375
# Epoch 127/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9937
# Epoch 127: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0125 - accuracy: 0.9937 - val_loss: 4.9351 - val_accuracy: 0.4458
# Epoch 128/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9927
# Epoch 128: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0206 - accuracy: 0.9927 - val_loss: 10.6956 - val_accuracy: 0.3333
# Epoch 129/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9823
# Epoch 129: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0496 - accuracy: 0.9823 - val_loss: 26.1697 - val_accuracy: 0.3333
# Epoch 130/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9906
# Epoch 130: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0516 - accuracy: 0.9906 - val_loss: 44.6892 - val_accuracy: 0.3333
# Epoch 131/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9896
# Epoch 131: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0206 - accuracy: 0.9896 - val_loss: 55.1294 - val_accuracy: 0.3333
# Epoch 132/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9917
# Epoch 132: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0161 - accuracy: 0.9917 - val_loss: 39.6852 - val_accuracy: 0.3333
# Epoch 133/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9979
# Epoch 133: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 24.6972 - val_accuracy: 0.3333
# Epoch 134/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9823
# Epoch 134: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0727 - accuracy: 0.9823 - val_loss: 121.1915 - val_accuracy: 0.3208
# Epoch 135/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9854
# Epoch 135: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0403 - accuracy: 0.9854 - val_loss: 61.0243 - val_accuracy: 0.3833
# Epoch 136/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9927
# Epoch 136: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0177 - accuracy: 0.9927 - val_loss: 1.8867 - val_accuracy: 0.3875
# Epoch 137/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9937
# Epoch 137: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0127 - accuracy: 0.9937 - val_loss: 3.7441 - val_accuracy: 0.3875
# Epoch 138/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.9865
# Epoch 138: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0344 - accuracy: 0.9865 - val_loss: 319.1682 - val_accuracy: 0.3333
# Epoch 139/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0679 - accuracy: 0.9823
# Epoch 139: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0679 - accuracy: 0.9823 - val_loss: 2.0357 - val_accuracy: 0.3542
# Epoch 140/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9917
# Epoch 140: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 998ms/step - loss: 0.0233 - accuracy: 0.9917 - val_loss: 4.0208 - val_accuracy: 0.3333
# Epoch 141/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9896
# Epoch 141: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0372 - accuracy: 0.9896 - val_loss: 3.3731 - val_accuracy: 0.3417
# Epoch 142/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9906
# Epoch 142: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 30s 1s/step - loss: 0.0214 - accuracy: 0.9906 - val_loss: 0.5852 - val_accuracy: 0.8667
# Epoch 143/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9917
# Epoch 143: val_accuracy did not improve from 0.97083
# 30/30 [==============================] - 31s 1s/step - loss: 0.0298 - accuracy: 0.9917 - val_loss: 0.1708 - val_accuracy: 0.9667
# Epoch 144/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9958
# Epoch 144: val_accuracy improved from 0.97083 to 0.97917, saving model to /content/drive/MyDrive/AI/datasets/arches/best_models/best_model_EfficientNetB3_val_accuracy_scratch.h5
# 30/30 [==============================] - 33s 1s/step - loss: 0.0159 - accuracy: 0.9958 - val_loss: 0.1254 - val_accuracy: 0.9792
# Epoch 145/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9958
# Epoch 145: val_accuracy did not improve from 0.97917
# 30/30 [==============================] - 30s 1s/step - loss: 0.0084 - accuracy: 0.9958 - val_loss: 0.1946 - val_accuracy: 0.9625
# Epoch 146/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9979
# Epoch 146: val_accuracy did not improve from 0.97917
# 30/30 [==============================] - 30s 1s/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.1213 - val_accuracy: 0.9792
# Epoch 147/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9969
# Epoch 147: val_accuracy did not improve from 0.97917
# 30/30 [==============================] - 30s 1s/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.7703 - val_accuracy: 0.8042
# Epoch 148/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9906
# Epoch 148: val_accuracy did not improve from 0.97917
# 30/30 [==============================] - 30s 1s/step - loss: 0.0238 - accuracy: 0.9906 - val_loss: 0.4444 - val_accuracy: 0.9000
# Epoch 149/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9906
# Epoch 149: val_accuracy did not improve from 0.97917
# 30/30 [==============================] - 31s 1s/step - loss: 0.0280 - accuracy: 0.9906 - val_loss: 5.1889 - val_accuracy: 0.3333
# Epoch 150/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9969
# Epoch 150: val_accuracy did not improve from 0.97917
# 30/30 [==============================] - 30s 1s/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 1.7335 - val_accuracy: 0.3333

# %%
import matplotlib.pyplot as plt

# Визуализация потерь
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss Evolution')

# Визуализация точности
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy Evolution')

plt.tight_layout()
datagen = ImageDataGenerator(rescale=1./255)
plt.show()

# %%
from tensorflow.keras.models import load_model

best_model_dir = '/content/drive/MyDrive/AI/datasets/arches/best_models/'

model = load_model(best_model_dir + 'best_model_EfficientNetB3_val_accuracy_scratch.h5')

# %%
TEST_DIR = '/content/drive/MyDrive/AI/datasets/arches/test/'
datagen = ImageDataGenerator(rescale=1./255)

test_generator = datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

loss, accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {accuracy}')
# Out:
# Found 214 images belonging to 3 classes.
# 7/7 [==============================] - 4s 224ms/step - loss: 0.6730 - accuracy: 0.9206
# Test accuracy: 0.9205607771873474

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Получить предсказания модели
y_pred = model.predict(test_generator, steps=len(test_generator))
y_pred_classes = np.argmax(y_pred, axis=1)

# Получить истинные метки классов
y_true = test_generator.classes

# Вычислить confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Отобразить confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 7/7 [==============================] - 4s 253ms/step
